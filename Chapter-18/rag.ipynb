# %% [markdown]
# # RAG piece-by-piece on Vertex AI
# In this notebook, we will build a RAG implementation piece by piece on Vertex AI.

# %% [markdown]
# ## Prerequisites
# **Note:** This notebook and repository are supporting artifacts for the "Google Machine Learning and Generative AI for Solutions Architects" book. The book describes the concepts associated with this notebook, and for some of the activities, the book contains instructions that should be performed before running the steps in the notebooks. Each top-level folder in this repo is associated with a chapter in the book. Please ensure that you have read the relevant chapter sections before performing the activities in this notebook.
#
# **There are also important generic prerequisite steps outlined [here](https://github.com/PacktPublishing/Google-Machine-Learning-for-Solutions-Architects/blob/main/Prerequisite-steps/Prerequisites.ipynb).**

# %% [markdown]
# **Attention:** The code in this notebook creates Google Cloud resources that can incur costs.
#
# Refer to the Google Cloud pricing documentation for details.
#
# For example:
#
# * [Vertex AI Pricing](https://cloud.google.com/vertex-ai/pricing)
# * [Document AI Pricing](https://cloud.google.com/document-ai/pricing)
# * [Google Cloud Storage Pricing](https://cloud.google.com/storage/pricing)

# %% [markdown]
# ## Background / overview
#
# There are many different ways to build RAG implementations on Vertex AI. In Chapter 17, we implemented a RAG solution using Vertex AI Search. Remember what we've mentioned numerous times throughout this book: When there are multiple potential ways of implementing a solution, a solution architecture best practice is to always use the most managed solution possible that meets yourn technical and business needs (which may include cost, but that cost should always be considered in terms of "total cost of ownership" (TCO), which includes the toil of building and managing solutions ourselves).
#
# For that reason, when implementing a RAG solution in Vertex AI, I recommend starting with Vertex AI Search, as we did in Chapter 17. However, if you want to build your own RAG solution from scratch, in which you perform document chunking and embedding explicitly yourself, you can use services such as Google Cloud Document AI and Vertex AI Vector Search (among others).

# %% [markdown]
# This notebook shows an example of using Google Cloud Document AI and Vertex AI Vector Search, as well as Google models such as Gemini and textembedding-gecko.

# %% [markdown]
# ## Solution Architecture
#
# The solution architecture is shown in the following diagram:
#
# <img src="images/RAG-Vertex.png">
#
# The steps in the diagram are described as follows:
#
# 1. Our documents, which are stored in Google Cloud Storage (GCS), are sent to Google Cloud Document AI for chunking. As the name suggests, the chunking process breaks the documents into “chunks,” which are smaller sections of the document. This is required in order to create standard-sized chunks that serve as inputs to the embedding process. The size of the chunks is configurable in Document AI, and further details on this process are described in the Jupyter Notebook.
# 2. The chunks are then sent to the Google Cloud “textembedding-gecko” LLM to create embeddings for the chunks. The resulting embeddings are stored in GCS, alongside their respective chunks (this step is omitted from the diagram).
# 3. We create a Vertex AI Vector Search index, and the embeddings are ingested from GCS to the Vertex AI Vector Search index (the GCS intermediary step is omitted from the diagram).
# 4. Next, the application/user asks a question that relates to the contents of our documents. The question is sent as a query to textembedding-gecko to be embedded/vectorized.
# 5. The vectorized query is then used as an input in a request to Vertex AI Vector Search, which searches our index to find similar embeddings. Remember that the embeddings represent an element of semantic meaning, so similar embeddings have similar meanings. This is how we can perform a semantic search to find embeddings that are similar to our query.
# 6. Next, we take the embeddings returned from our Vertex AI Vector Search query and find the chunks in GCS that relate to those embeddings (remember that Step 2 in our solution created a stored association of chunks and embeddings).
# 7. Now, it’s finally time to send a prompt to Gemini. The retrieved document chunks from Step 6 serve as context for the prompt. This helps Gemini to respond to our prompt based on the relevant contents from our documents and not just from its pre-trained knowledge.
# 8. Gemini responds to the prompt.
#
# Note, between some of the steps depicted in the diagram, Google Cloud Storage is used to store the inputs and outputs of each step, but those intermediary processes are omitted to make the diagram more readable. Also, when we implement this solution here in our Jupyter Notebook, the notebook is the “application/user” that coordinates each of the steps in the overall process.
#
# Also, in this case, we are using documents stored in GCS as our source of truth, but we could also use other data, such as data stored in BigQuery.

# %% [markdown]
# ## Document/data citation
# The citation for the document used in this exercise is as follows:
#
# *Hila Zelicha, Jieping Yang, Susanne M Henning, Jianjun Huang, Ru-Po Lee, Gail Thames, Edward H Livingston, David Heber, and Zhaoping Li, 2024. Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial. DOI:https://doi.org/10.1016/j.ajcnut.2024.01.008*

# %% [markdown]
# # Implementation steps

# %% [markdown]
# ## Install packages

# %%
# %pip install --upgrade --quiet google-cloud-aiplatform google-cloud-storage google-cloud-documentai vertexai
# Out:
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# *The pip installation commands sometimes report various errors. Those errors usually do not affect the activities in this notebook, and you can ignore them.*

# %% [markdown]
# ## Restart the kernel
#
# The code in the next cell will retart the kernel, which is sometimes required after installing/upgrading packages.
#
# **When prompted, click OK to restart the kernel.**
#
# The sleep command simply prevents further cells from executing before the kernel restarts.

# %%
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time
time.sleep(10)

# %% [markdown]
# # (Wait for kernel to restart before proceeding...)

# %% [markdown]
# ## Set Google Cloud resource variables
#
# The following code will set variables specific to your Google Cloud resources that will be used in this notebook, such as the Project ID, Region, and GCS Bucket.
#
# **Note: This notebook is intended to execute in a Vertex AI Workbench Notebook, in which case the API calls issued in this notebook are authenticated according to the permissions (e.g., service account) assigned to the Vertex AI Workbench Notebook.**
#
# We will use the `gcloud` command to get the Project ID details from the local Google Cloud project, and assign the results to the PROJECT_ID variable. If, for any reason, PROJECT_ID is not set, you can set it manually or change it, if preferred.
#
# We also use a default bucket name for most of the examples and activities in this book, which has the format: `{PROJECT_ID}-aiml-sa-bucket`. You can change the bucket name if preferred.
#
# Also, we're defaulting to the **us-central1** region, but you can optionally replace this with your [preferred region](https://cloud.google.com/about/locations).

# %%
PROJECT_ID_DETAILS = !gcloud config get-value project
PROJECT_ID = PROJECT_ID_DETAILS[0]  # The project ID is item 0 in the list returned by the gcloud command
PROJECT_NUMBER_DETAILS = !gcloud projects describe $PROJECT_ID --format="value(projectNumber)" 
PROJECT_NUMBER = PROJECT_NUMBER_DETAILS[0]  # The project number is item 0 in the list returned by the gcloud command 
BUCKET=f"{PROJECT_ID}-aiml-sa-bucket" # Optional: replace with your preferred bucket name, which must be a unique name.
REGION="asia-northeast3" # Optional: replace with your preferred region (See: https://cloud.google.com/about/locations) 
print(f"Project ID: {PROJECT_ID}")
print(f"Project Number: {PROJECT_NUMBER}")
print(f"Bucket Name: {BUCKET}")
# Out:
# Project ID: ds-on-gsp
# Project Number: 714662258896
# Bucket Name: ds-on-gsp-aiml-sa-bucket

# %% [markdown]
# ## Create bucket
#
# The following code will create the bucket if it doesn't already exist.
#
# If you get an error saying that it already exists, that's fine, you can ignore it and continue with the rest of the steps, unless you want to use a different bucket.

# %%
# !gsutil mb -l us-central1 gs://{BUCKET}
# Out:
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update
#
# Creating gs://ds-on-gsp-aiml-sa-bucket/...

# %% [markdown]
# ## Begin implementation
#
# Now that we have performed the prerequisite steps for this activity, it's time to implement the activity.

# %% [markdown]
# ### Create UID for this session
#
# This will be used in various variable values throughout this notebook to make the values unique to this session.

# %%
from datetime import datetime

# generate a unique id for this session
UID = datetime.now().strftime("%m%d%H%M")

# %% [markdown]
# ## Create Document AI Processor
#
# We will create a Document AI Processor to break our input documents into chunks.
#
# See documentation [here](https://cloud.google.com/document-ai/docs/overview#dai-processors) and [here](https://cloud.google.com/document-ai/docs/layout-parse-chunk) for additional details.

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import documentai

# Document AI Variables
location = 'us'  # # Different from REGION; the format is 'us' or 'eu'
processor_display_name = f"RAG-Chunking-Processor-{UID}"
processor_type = 'LAYOUT_PARSER_PROCESSOR'

# Create Document AI client
opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")
client = documentai.DocumentProcessorServiceClient(client_options=opts)

# Location path
parent = client.common_location_path(PROJECT_NUMBER, location)

# Create the processor 
processor = client.create_processor(
    parent=parent,
    processor=documentai.Processor(
        display_name=processor_display_name, type_=processor_type
    ),
)

# Print the processor information
print(f"Processor Name: {processor.name}")
print(f"Processor Display Name: {processor.display_name}")
print(f"Processor Type: {processor.type_}")
print(f"Processor State: {processor.state}")

processor_name = processor.name  # Get the processor name for later use
# Out:
# Processor Name: projects/714662258896/locations/us/processors/e3e6ae448e857d12
# Processor Display Name: RAG-Chunking-Processor-01201941
# Processor Type: LAYOUT_PARSER_PROCESSOR
# Processor State: 1

# %% [markdown]
# ## Process the document to create the chunks
#
# This is the point at which we perform document chunking.
#
# The following code will use our Document AI processor to break our document into chunks.

# %%
from typing import Optional
from google.cloud import documentai_v1beta3 as documentai

file_path = "data/Cinnamon.pdf"
mime_type = "application/pdf" # Refer to https://cloud.google.com/document-ai/docs/file-types for supported file types

def process_document_sample(
    project_id: str,
    location: str,
    processor_name: str,
    file_path: str,
    mime_type: str,
) -> None:
    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")

    name = processor_name
    client = documentai.DocumentProcessorServiceClient(client_options=opts)

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Load binary data
    raw_document = documentai.RawDocument(content=image_content, mime_type=mime_type)

    # For more information: https://cloud.google.com/document-ai/docs/reference/rest/v1/ProcessOptions

    # Define the main configuration dictionary
    process_options = documentai.ProcessOptions(
        layout_config=documentai.ProcessOptions.LayoutConfig(
            chunking_config=documentai.ProcessOptions.LayoutConfig.ChunkingConfig(
                chunk_size=200,  
                include_ancestor_headings=True
            )
        )
    )

    # Configure the process request
    request = documentai.ProcessRequest(
        name=name,
        raw_document=raw_document,
        process_options=process_options,
    )
    
    result = client.process_document(request=request)

    # For a full list of `Document` object attributes, reference this page:
    # https://cloud.google.com/document-ai/docs/reference/rest/v1/Document
    document = result.document
    return document

document_object = process_document_sample(PROJECT_NUMBER, location, processor_name, file_path, mime_type)

doc_layout = document_object.document_layout
chunked_doc = document_object.chunked_document

# %%
document_object
# Out:
# document_layout {
#   blocks {
#     block_id: "1"
#     text_block {
#       text: "ASN"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "2"
#     text_block {
#       text: "EST. 1928"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "3"
#     text_block {
#       text: "American Society for Nutrition"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "4"
#     text_block {
#       text: "Excellence in Nutrition Research and Practice"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "5"
#     text_block {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "6"
#     text_block {
#       text: "The American Journal of"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "7"
#     text_block {
#       text: "CLINICAL NUTRITION"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "8"
#     text_block {
#       text: "journal homepage: https://ajcn.nutrition.org/"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "9"
#     text_block {
#       text: "The merican Journal CLINICAL NUTRITION"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "10"
#     text_block {
#       text: "Original Research Article"
#       type_: "paragraph"
#     }
#     page_span {
#       page_start: 1
#       page_end: 1
#     }
#   }
#   blocks {
#     block_id: "11"
#     text_block {
#       text: "Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial"
#       type_: "heading-1"
#       blocks {
#         block_id: "12"
#         text_block {
#           text: "Hila Zelicha¹, Jieping Yang 2, Susanne M Henning 2, Jianjun Huang 2, Ru-Po Lee2, Gail Thames 2, Edward H Livingston¹, David Heber², Zhaoping Li 2,*"
#           type_: "paragraph"
#         }
#         page_span {
#           page_start: 1
#           page_end: 1
#         }
#       }
#       blocks {
#         block_id: "13"
#         text_block {
#           text: "Department of Surgery, University of California, Los Angeles, Los Angeles, CA, United States; 2 Department of Medicine, Center for Human Nutrition, David Geffen School of Medicine, Los Angeles, United States"
#           type_: "paragraph"
#         }
#         page_span {
#           page_start: 1
#           page_end: 1
#         }
#       }
#       blocks {
#         block_id: "14"
#         text_block {
#           text: "ABSTRACT"
#           type_: "heading-2"
#           blocks {
#             block_id: "15"
#             text_block {
#               text: "Check for updates"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "16"
#             text_block {
#               text: "Background: Previous clinical studies showing that cinnamon spice lowers blood glucose concentrations had inconsistent results. Objectives: To determine the effect of daily cinnamon spice supplementation in an amount commonly used for seasoning on glucose concentrations in adults with obesity and prediabetes."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "17"
#             text_block {
#               text: "Methods: Following a 2-wk run-in period of maintaining a low polyphenol/fiber diet, 18 participants with obesity and prediabetes underwent a 10-wk randomized, controlled, double-blind, crossover trial (mean age 51.1 y; mean fasting plasma glucose 102.9~mg/dL). The participants were randomly assigned to take cinnamon (4~g/d) or placebo for 4-wk, followed by a 2-wk washout period, and then crossed over to the other intervention for an additional 4-wk. Glucose changes were measured with continuous glucose monitoring. Oral glucose tolerance testing immediately following ingestion of cinnamon or placebo was performed at 4-time points to assess their acute effects both at the baseline and end of each intervention phase. Digestive symptom logs were obtained daily."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "18"
#             text_block {
#               text: "Results: There were 694 follow-up days with 66,624 glucose observations. When compared with placebo, 24-h glucose concentrations were significantly lower when cinnamon was administered [mixed-models; effect size (ES) = 0.96; 95% confidence interval (CI): -2.9, -1.5; P<0.0017. Similarly, the mean net-area-under-the-curve (netAUC) for glucose was significantly lower than for placebo when cinnamon was given (over 24 h; ES=-0.66:95\\% CI: 2501.7, 5412.1, P=0.01). Cinnamon supplementation resulted in lower glucose peaks compared with placebo (Apeak 9.56\\pm9.1~mg/dI compared with 11.73\\pm8.0~mg/dL; ES = -0.57; 95% CI: 0.8, 3.7, P=0.027). Glucose-dependent-insulinotropic-polypeptide concentrations increased during oral glucose tolerance testing + cinnamon testing (mixed-models; ES = 0.51; 95% CI: 1.56, 100.1, P=0.04, whereas triglyceride concentrations decreased (mixed-models; ES=0.55; 95% CI: -16.0, -1.6, P=0.02. Treatment adherence was excellent in both groups (cinnamon: 97.6\\pm3.4\\% compared with placebo: 979+37\\%; ES=-0.15. 95% CI: -1.8, 0.2, P=0.5. No differences were found in digestive symptoms (abdominal pain, borborygmi, bloating, excess flatus, and stools/day) between cinnamon and placebo groups."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "19"
#             text_block {
#               text: "Conclusions: Cinnamon, a widely available and low-cost supplement, may contribute to better glucose control when added to the diet in people who have obesity-related prediabetes."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "20"
#             text_block {
#               text: "This trial was registered at clinicaltrials.gov as NCT04342624."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "21"
#             text_block {
#               text: "Keywords: cinnamon, continuous glucose system, glycemic response, polyphenols, prediabetes"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#         }
#         page_span {
#           page_start: 1
#           page_end: 1
#         }
#       }
#       blocks {
#         block_id: "22"
#         text_block {
#           text: "Introduction"
#           type_: "heading-2"
#           blocks {
#             block_id: "23"
#             text_block {
#               text: "Cinnamon contains polyphenols, which may improve glucose ho- meostasis, but studies of its influence on glucose changes have had mixed results [1-4]. Cinnamon\'s ability to affect glucose control re- mains uncertain. Studies have previously shown that cinnamon"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "24"
#             text_block {
#               text: "lowered glucose and lipid concentrations in patients with type 2 dia- betes [5-8], prediabetes [9,10], and in healthy adults [11-14]. How- ever, other studies have yielded contrary results [1-4]. Cinnamon doses in these studies were highly variable, ranging from 0.5 g up to 6~g/d, with study durations varying from 4 to 12 wk [5,7,8,10-12]. Reviews and meta-analyses suggest that supplemental cinnamon or cinnamon"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "25"
#             text_block {
#               text: "Abbreviations: CGM, continuous glucose monitoring; CI, confidence interval; ES, effect size; FPG, fasting plasma glucose; GIP, glucose-dependent-insulinotropic-polypeptide; ITT, intention-to-treat; OGTT, oral glucose tolerance test; SCFA, short-chain fatty acid."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "26"
#             text_block {
#               text: "This article was presented in an abstract form at the American Society for Nutrition (ASN) conference in July 2023 in Boston, MA, USA. * Corresponding author."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "27"
#             text_block {
#               text: "E-mail address: zli@mednet.ucla.edu (Z. Li)."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "28"
#             text_block {
#               text: "https://doi.org/10.1016/j.ajcnut.2024.01.008"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "29"
#             text_block {
#               text: "Received 3 July 2023; Received in revised form 3 January 2024; Accepted 9 January 2024; Available online 26 January 2024 0002-9165/Published by Elsevier Inc. on behalf of American Society for Nutrition. This is an open access article under the CC BY license (http://creativecommons.org/licenses/by/4.0/)."
#               type_: "footer"
#             }
#             page_span {
#               page_start: 1
#               page_end: 1
#             }
#           }
#           blocks {
#             block_id: "30"
#             text_block {
#               text: "H. Zelicha et al."
#               type_: "header"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "31"
#             text_block {
#               text: "extracts may lower blood glucose concentrations [15-22]; however, inconsistent findings of cinnamon on glycemic control from studies that had small effect sizes (ESs) or very heterogeneous results [15-22] indicate a need for further research."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "32"
#             text_block {
#               text: "We conducted a 4-wk randomized, controlled, double-blind cross- over trial to evaluate the effects of cinnamon consumption on glucose changes throughout the day, as measured by continuous glucose monitoring (CGM) in participants with prediabetes and obesity. We also assessed glucose, metabolic, and hormonal responses to oral glucose tolerance tests (OGTTs) during acute administration of cin- namon and glucose using a modified OGTT protocol at 4 different time points during the study. Blood and fecal short-chain fatty acids (SCFAs) concentrations were measured by gas chromatography. We hypothesized that cinnamon spice consumption results in sustained lowering of blood glucose concentrations."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#         }
#         page_span {
#           page_start: 1
#           page_end: 2
#         }
#       }
#       blocks {
#         block_id: "33"
#         text_block {
#           text: "Methods"
#           type_: "heading-2"
#         }
#         page_span {
#           page_start: 2
#           page_end: 2
#         }
#       }
#       blocks {
#         block_id: "34"
#         text_block {
#           text: "Study design"
#           type_: "heading-2"
#           blocks {
#             block_id: "35"
#             text_block {
#               text: "This was a total of 12-wk randomized, controlled, double-blind, crossover trial, which started with a 2-wk run-in phase (NCT04342624; Figure 1; Supplemental Table 1). Enrollment began in March 2021 and ended in September 2021, with the overall study ending in December 2021. Patients were eligible for study inclusion if they were healthy adults older than 18 y who consumed a low fiber/ polyphenol diet, adults, overweight or obese [BMI in (kg/m^{2}) between"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "36"
#             text_block {
#               text: "25-40], and had prediabetes defined as having fasting plasma glucose (FPG) between 100-125~mg/dL or hemoglobin Alc (HbA1c) con- centrations between 5.7-6.4% (39-47~mmol/mol) [23]. A compre- hensive metabolic panel and HbAlc were drawn when initially screened for the study. Detailed exclusion criteria are listed in Sup- plemental Data 1. Participants read and signed the institutional review board-approved written informed consent and Health Insurance Portability and Accountability Act (HIPAA) authorization before initiating any study-specific procedures or enrollment. The study design was carried out in accordance with the guidelines of the Human Subjects Protection Committee of the University of California, Los Angeles. Of the 19 participants who were enrolled in the study, 1 declined to participate after not tolerating the insertion of the CGM probe and was not randomly assigned (Figure 1)."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "37"
#             text_block {
#               text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#               type_: "header"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#         }
#         page_span {
#           page_start: 2
#           page_end: 2
#         }
#       }
#       blocks {
#         block_id: "38"
#         text_block {
#           text: "Randomization"
#           type_: "heading-2"
#           blocks {
#             block_id: "39"
#             text_block {
#               text: "Randomization was performed by the study statistician after sub- jects met all eligibility criteria and completed baseline evaluations. Subjects were randomly assigned to 1 of 2 capsules (A or B) containing cinnamon or placebo. The randomization used a permuted block design with a random block size of 4."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#         }
#         page_span {
#           page_start: 2
#           page_end: 2
#         }
#       }
#       blocks {
#         block_id: "40"
#         text_block {
#           text: "Intervention"
#           type_: "heading-2"
#           blocks {
#             block_id: "41"
#             text_block {
#               text: "In this randomized, controlled, double-blind, crossover trial, par- ticipants started with a 2-wk run-in phase by consuming a low poly- phenol beige diet (included foods typically beige in color and rich in simple carbohydrates and were asked to avoid any cinnamon or cin- namon products; Supplemental Table 2). This diet was maintained for the entire 12 wk of the study. After the 2-wk run-in phase, the partic- ipants were randomly assigned to ingest cinnamon (16~capsules-4~g/d) or placebo for 4 wk, followed by a 2-wk washout phase, then crossed over to the other intervention for an additional 4 wk (allocation ratio 1:1). Three-day food intake records were obtained during the screening process and at subsequent clinical visits. Patient eligibility for the study was determined during screening by assessing the participants\' dietary habits and compliance with the low fiber/polyphenol diet, which was based on the analysis of their 3-d food records and consultations with a dietitian. Participants were given a low fiber/polyphenol diet handout providing nutritional guidance about the diet that was maintained for the study duration. Cinnamon (C. burmannii - Indonesian cinnamon) was administered in 250 mg capsules. Participants took 8 capsules with breakfast and 8 capsules with dinner (16 capsules or 4~g/d). Participants took the same number of placebo capsules that contained 250 mg of maltodextrin and were identical such that the participants could not tell the difference between them. The chemical profile of the cinnamon powder used in this study was analyzed and found to contain 3.64\\pm 0.04~mg/g of coumarin, 1.02\\pm0.01~mg/g of cinnamic acid, and 29.03 \\pm0.15~mg/g cinnamaldehyde (coumarin: 0.17~mg/kg body weight, cinnamic acid is 0.054~mg/kg body weight, and cinnamaldehyde is 1.55~mg/kg body weight; Supplemental Data 2). Capsules were com- pounded by Tele-Travel Services (Thousand Oaks, CA). The study was double-blinded, with neither the participants nor the researchers knowing if the participants received cinnamon or placebo. Glucose monitoring was performed by use of a flash system device (FreeStyle Libre Pro; Abbott Diabetes Care, Alameda, CA). Validation of the flash"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "42"
#             text_block {
#               text: "Study population (n=19)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "43"
#             text_block {
#               text: "Cinnamon (n=9)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "44"
#             text_block {
#               text: "Randomized (n=18)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "45"
#             text_block {
#               text: "Placebo (n=9)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "46"
#             text_block {
#               text: "Beige diet (low polyphenol diet)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "47"
#             text_block {
#               text: "Cinnamon ((n=9)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "48"
#             text_block {
#               text: "Placebo (n=9)"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "49"
#             text_block {
#               text: "-2"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "50"
#             text_block {
#               text: "0"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "51"
#             text_block {
#               text: "4"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "52"
#             text_block {
#               text: "6"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "53"
#             text_block {
#               text: "Enrollment"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "54"
#             text_block {
#               text: "Run-in"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "55"
#             text_block {
#               text: "Intervention"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "56"
#             text_block {
#               text: "Washout"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "57"
#             text_block {
#               text: "Intervention"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "58"
#             text_block {
#               text: "FIGURE 1. Participant flow chart for the crossover study design."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "59"
#             text_block {
#               text: "650"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "60"
#             text_block {
#               text: "10"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "61"
#             text_block {
#               text: "圓"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 2
#               page_end: 2
#             }
#           }
#           blocks {
#             block_id: "62"
#             text_block {
#               text: "H. Zelicha et al."
#               type_: "header"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#           blocks {
#             block_id: "63"
#             text_block {
#               text: "system device\'s accuracy can be found in Supplemental Data 3. The device was reapplied every 2 wk during the study (Figure 1: weeks 0, 2, 6, 8; Supplemental Data 3). Each participant recorded their cinnamon/ placebo capsule intake in a diary. A weekly medication dispenser was provided to assist subjects in managing their daily capsule intake. At the end of the study, the remaining capsules were counted, and compliance was calculated. Compliance was defined as having consumed 75% or more of the capsules. Participants also recorded digestive symptoms (abdominal pain, borborygmi, bloating, excess flatus, number of stools/day) daily throughout the study."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#         }
#         page_span {
#           page_start: 2
#           page_end: 3
#         }
#       }
#       blocks {
#         block_id: "64"
#         text_block {
#           text: "Oral glucose tolerance testing following cinnamon or placebo ingestion"
#           type_: "heading-2"
#           blocks {
#             block_id: "65"
#             text_block {
#               text: "OGTT was performed at 4-time points (Figure 1; Supplemental Table 1): 1) baseline (time period #0- after the 2-wk run-in phase), 2) time period #4- after the first 4-wk intervention period, 3) time period #6- following the 2-wk washout time period, 4) time period #10- after the second 4-wk intervention period. On each testing day, subjects were evaluated at the University of California, Los Angeles Center for Human Nutrition following an 8-12 h fast. An indwelling catheter was inserted into a forearm vein, and a baseline (0 h) fasting blood sample was collected. Between blood draws, the catheter was flushed with saline through it for the entire experiment to prevent clothing or blockages. A trained nurse was responsible for the entire OGTT pro- cedure. She was responsible for ensuring that the cannula remained patent, collecting blood samples at the correct time intervals, and addressing any complications that may arise. The subjects then ingested 75 g of glucose cola within a 5-min time period along with 8 capsules (2 g) of cinnamon or placebo. Blood samples (10 mL) were drawn every 30 min for 3 h. Glucose, insulin, C-peptide, glucagon, glucose-dependent-insulinotropic-polypeptide (GIP), Glucagon-like Peptide-1, and triglyceride concentrations (Supplemental Data 4) were measured. A stool sample was collected the day before each visit (4 visit days; Supplemental Table 1; Supplemental Data 5). Weight, body composition, and systolic and diastolic blood pressure were measured after participants arrived at the Center for Human Nutrition at each visit after resting for 15 min (Supplemental Table 1). Percent body fat, fat mass, lean body mass, total body water, and basal metabolic rate were measured using bioelectrical impedance (BIA310e; Biodynamics Corporation, Tanita-BC418 body-fat analyzer; Tanita Corporation) [7]. Blood and fecal SCFA content were analyzed by gas chromatography. The concentrations of serum and fecal acetic, propionic, butyric, iso- butyric, valeric, and isovaleric acids were quantified. Additional in- formation regarding gut microbiome and serum and fecal SCFA analysis are found in Supplemental Data 5."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#         }
#         page_span {
#           page_start: 3
#           page_end: 3
#         }
#       }
#       blocks {
#         block_id: "66"
#         text_block {
#           text: "Statistical analysis"
#           type_: "heading-2"
#           blocks {
#             block_id: "67"
#             text_block {
#               text: "The primary objective of this trial was to assess the effect of 4~g/d of cinnamon spice supplementation on continuous glycemic response in participants who had obesity and prediabetes. The primary outcome was the continuously measured glucose concentrations. Secondary outcomes included the effects of cinnamon on 1) the glycemic response to an OGTT, 2) anthropometric parameters and body composition, and 3) SCFA and the microbiome. The primary analytic approach was per protocol, and an intention-to-treat (ITT) approach was assessed as a sensitivity analysis. Missing data were modeled using multiple impu- tations, assuming observations were missing completely at random (Supplemental Figure 1) [24]. Sample size estimation was based on a"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#           blocks {
#             block_id: "68"
#             text_block {
#               text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#               type_: "header"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#           blocks {
#             block_id: "69"
#             text_block {
#               text: "prior study where 3~g/d ingestion of cinnamon for 40 d resulted in a reduction of fasting serum glucose from 11.4\\pm1.2~mmol/L to 9.4\\pm 1.1~mmol/L [5]. Based on these results, 14 participants would be needed to achieve 80% power, and 18 participants would be needed for 90% power to detect a significant reduction in fasting glucose con- centrations of 2~mmol/L with a 2-sided significance level of 0.05 [5]. Recalculation of study power based on our sample size (n=18) and anticipating a reduction in glucose of 2~mmol/L and a 2-sided signif- icance level of 0.05 yielded a study power of 93.8% [5]. Continuous variables were presented as mean ± SD unless specified otherwise. Categorical variables were expressed as percentages with IQRs. Baseline characteristics were presented for the entire study population. Participants were seen in the clinic every 2 wk for the placement of CGM sensors. These visits occurred in the morning, at ~08:00. CGM data for each individual were collected and organized into daily seg- ments (24 h - from around 08:00 to 08:00). To establish the start time for each day, we calculated the mean time of day the glucose sensor was applied for each person (start time ranged between 07:30 and 08:30). We excluded days that were not representative of normal daily activity, such as days when OGTT was performed and the first 24 h after applying the sensor. We calculated the mean glucose concentra- tions (every 15~min/d) for each participant for the 2 interventions (cinnamon or placebo). Eventually, we had a day with 96 glucose mean observations (every 15 min) for each intervention. Glucose concen- trations were reported as changing relative to the initial glucose mea- surement. CGM data processing was performed by an analyst blinded to the intervention (HZ). Statistical analysis was performed by an un- blinded investigator. Glucose changes were assessed by calculation of the glucose AUC using the net incremental AUC method (netAUC) [25-27]. NetAUC calculation includes the areas below a curve, both above and below the level of fasting time periods. The netAUC can result in values <0 since it is calculated as positive and negative blood glucose increments. Within-subject differences were determined by estimating the mean net incremental area under the 24-h glucose-time curve [25-27] and tested for statistical significance using Wilcoxon Signed rank testing. Individual glycemic-response parameters were also determined: peak glucose height, peak start time, time to glucose peak, and mean peak duration. Peak values were determined from the difference of the highest measurement relative to the mean glucose concentration for the corresponding time period. Statistical significance between cinnamon and placebo glycemic responses was determined by Wilcoxon Signed rank testing. Mixed-model analysis was used to evaluate the difference between cinnamon and placebo CGM trajec- tories (the pattern of serial glucose readings taken at different time points), taking into account within and between-subject differences. Mixed-model analysis was performed, treating subjects as random effects (within-subject test) with the intervention as a fixed effect (between-subject factor) and the outcome being the glucose concen- tration. Additional adjustments for potential confounders were added to the model (sex, age, and FPG at baseline/HbA1c at baseline/systolic or diastolic blood pressure). Mixed-model analysis was also used in the OGTT analysis (every 30 min over 3 h after glucose load). Exploratory analysis comparing differences between various time points during OGTT used Bonferroni correction for multiple comparisons. Addi- tionally, we assessed insulin sensitivity with the OGTT test using the Matsuda Index: [10,000 /√(FPG x fasting plasma insulin) X (mean glucose OGTT x mean insulin OGTT)] [28]. Differences between cinnamon and placebo effects on serum and fecal SCFA, anthropo- metric, and body composition measurement ...
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#           blocks {
#             block_id: "70"
#             text_block {
#               text: "651"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 3
#               page_end: 3
#             }
#           }
#           blocks {
#             block_id: "71"
#             text_block {
#               text: "H. Zelicha et al."
#               type_: "header"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#           blocks {
#             block_id: "72"
#             text_block {
#               text: "Wilcoxon Signed rank test. Analysis of covariance model was used to evaluate the differences in body composition and anthropometric adjusted for age, sex, and baseline measurements. Potential carryover effects from the first phase treatment allocation were minimized with the 2-wk washout period that should have been sufficiently long for the cinnamon effect to be depleted [4]. The washout period in our study is consistent with previous publications that employed a washout period of 7-20 d (2,5,6). The risk of potential carryover effects was evaluated by the interaction of the intervention order and the treatment in repeated mixed-models [29]. Effect size was calculated as Eta-squared (\\eta^{2}). Statistical significance was assumed if the 2-sided P<0.05. Statistical analysis was performed using IBM SPSS Statistics, version 29.0 software. Graphs were constructed using GraphPad Prism 9 by Dot- matics. Further detailed statistical analysis is presented in Supple- mental Data 6."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#         }
#         page_span {
#           page_start: 3
#           page_end: 4
#         }
#       }
#       blocks {
#         block_id: "73"
#         text_block {
#           text: "Results"
#           type_: "heading-2"
#         }
#         page_span {
#           page_start: 4
#           page_end: 4
#         }
#       }
#       blocks {
#         block_id: "74"
#         text_block {
#           text: "Baseline characteristics"
#           type_: "heading-2"
#           blocks {
#             block_id: "75"
#             text_block {
#               text: "The baseline characteristics of all participants are shown in Table 1. There were 13 females (72%), the mean ± SD age was 51.1\\pm10.4~y, and the mean weight was 84.6\\pm15.8~k kg (BMI: 31.5\\pm4.3). The mean FPG concentration was 102.9\\pm13.6~mg/dL, with a mean HbA1c of 5.9\\pm0.4\\% (41.1\\pm4.3~mmol/mol). Baseline parameters were simi- larly distributed among the participants who started first with cinnamon or a placebo."
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#         }
#         page_span {
#           page_start: 4
#           page_end: 4
#         }
#       }
#       blocks {
#         block_id: "76"
#         text_block {
#           text: "CGM"
#           type_: "heading-2"
#           blocks {
#             block_id: "77"
#             text_block {
#               text: "There was a total of 694 follow-up days with 66,624 glucose ob- servations (every 15 min). Three participants were excluded because of missing glucose observations from 1 of the interventions. The glucose trajectories over 24 h after cinnamon spice supplementation and pla- cebo administration are presented in Figure 2. The characteristics of the"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#           blocks {
#             block_id: "78"
#             text_block {
#               text: "TABLE 1"
#               type_: "heading-3"
#               blocks {
#                 block_id: "79"
#                 text_block {
#                   text: "Baseline characteristics of the study participants"
#                   type_: "paragraph"
#                 }
#                 page_span {
#                   page_start: 4
#                   page_end: 4
#                 }
#               }
#               blocks {
#                 block_id: "80"
#                 text_block {
#                   text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#                   type_: "header"
#                 }
#                 page_span {
#                   page_start: 4
#                   page_end: 4
#                 }
#               }
#               blocks {
#                 block_id: "81"
#                 text_block {
#                   text: "continuous glucose measures are shown in Supplemental Table 3. Cinnamon supplementation resulted in lower glucose peaks (\\Delta=9.56 \\pm9.1~mg/dL) compared with placebo [\\Delta=11.73\\pm8.0~mg/dL ES = -0.57, 95% confidence interval (CI): 0.8, 3.7, P=0.027] (Figure 2). Cinnamon consumption reduced mean netAUC over 24 h compared with placebo (cinnamon: -1265.2\\pm9027.3~mg/dL^{*} min compared with placebo: 1914.6\\pm9223.4~mg/dL^{*} min, ES=-0.66, 95% CI: 2501.7, 5412.1, P=0.01). The overall repeated glucose concentrations over 24 h were significantly lower at all time points in the cinnamon intervention compared with the placebo (ES = 0.96, 95% CI: -2.9, -1.5, P<0.001. The mean starting peak time, the time to peak, and the mean duration of the peaks were not significantly different between the interventions (P>0.05; Supplemental Table 3). The difference in the glucose trajectories between cinnamon and placebo remained strongly significant after adjusting for age, sex, and HbA1c at baseline/ FPG at baseline/systolic or diastolic blood pressure at baseline per- formed in multivariable repeated measurement models (P<0.001). The potential for the carryover effect of cinnamon from the initial to the final time period was evaluated by testing for an interaction between treatments, and the order of intervention allocation was not statistically significant (P=0.5). Individual continuous blood glucose concentra- tions are presented in Supplemental Figure 2. ITT analysis showed similar results between the imputed results and the perprotocol data. The ITT analysis can be found in Supplemental Figure 1. Sensitivity analysis exploring continuous glucose trajectories after cinnamon ingestion compared with placebo, excluding participants number 2, 5, 12, and 15, was similar to the perprotocol analysis (Supplemental Figure 3)."
#                   type_: "paragraph"
#                 }
#                 page_span {
#                   page_start: 4
#                   page_end: 4
#                 }
#               }
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#         }
#         page_span {
#           page_start: 4
#           page_end: 4
#         }
#       }
#       blocks {
#         block_id: "82"
#         text_block {
#           text: "Oral glucose tolerance testing"
#           type_: "heading-2"
#           blocks {
#             block_id: "83"
#             text_block {
#               text: "OGTT administered at baseline and following cinnamon or placebo ingestion are presented in Figure 3. Cinnamon supplementation led to a statistically significant increase in the GIP AUC-180 min"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#           blocks {
#             block_id: "84"
#             text_block {
#               text: "(n=18)^{1}"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#           blocks {
#             block_id: "85"
#             text_block {
#               text: "†"
#               type_: "paragraph"
#             }
#             page_span {
#               page_start: 4
#               page_end: 4
#             }
#           }
#           blocks {
#             block_id: "86"
#             table_block {
#               body_rows {
#                 cells {
#                   blocks {
#                     block_id: "87"
#                     text_block {
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "88"
#                     text_block {
#                       text: "Entire sample size n=18"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "89"
#                     text_block {
#                       text: "Intervention 1 order * (n=9)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "90"
#                     text_block {
#                       text: "Intervention 2 order (n=9)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#               }
#               body_rows {
#                 cells {
#                   blocks {
#                     block_id: "91"
#                     text_block {
#                       text: "Age, y Females (%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "92"
#                     text_block {
#                       text: "51.1\\pm10.4 13 (72%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "93"
#                     text_block {
#                       text: "50.0\\pm7.0 7 (78%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "94"
#                     text_block {
#                       text: "52.2\\pm13.4 6 (67%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#               }
#               body_rows {
#                 cells {
#                   blocks {
#                     block_id: "95"
#                     text_block {
#                       text: "Hispanic population (%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "96"
#                     text_block {
#                       text: "8 (44%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "97"
#                     text_block {
#                       text: "4 (44%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "98"
#                     text_block {
#                       text: "4 (44%)"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#               }
#               body_rows {
#                 cells {
#                   blocks {
#                     block_id: "99"
#                     text_block {
#                       text: "Race"
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "100"
#                     text_block {
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
#                     block_id: "101"
#                     text_block {
#                       type_: "paragraph"
#                     }
#                     page_span {
#                       page_start: 4
#                       page_end: 4
#                     }
#                   }
#                   row_span: 1
#                   col_span: 1
#                 }
#                 cells {
#                   blocks {
# ...
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c56"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[11] T.P. Solomon, A.K. Blannin, Effects of short-term cinnamon ingestion on in vivo glucose tolerance, Diabetes Obes. Metab. 9 (6) (2007) 895-901. [12] T.P. Solomon, A.K. Blannin, Changes in glucose tolerance and insulin sensitivity following 2 weeks of daily cinnamon ingestion in healthy humans, Eur. J Appl. Physiol. 105 (6) (2009) 969-976. [13] J. Hlebowicz, G. Darwiche, O. Björgell, L.O. Almér, Effect of cinnamon on postprandial blood glucose, gastric emptying, and satiety in healthy subjects2, Am. J Clin. Nutr. 85 (6) (2007) 1552-1556. [14] J. Hlebowicz, A. Hlebowicz, S. Lindstedt, O. Björgell, P. Höglund, J.J. Holst, et al., Effects of 1 and 3 g cinnamon on gastric emptying, satiety, and postprandial blood glucose, insulin, glucose-dependent insulinotropic polypeptide, glucagon-like peptide 1, and ghrelin concentrations in healthy subjects, Am. J Clin. Nutr. 89 (3) (2009) 815-821. [15] R.W. Allen, E. Schwartzman, W.L. Baker, C.I. Coleman, O.J. Phung, Cinnamon use in type 2 diabetes: an updated systematic review and meta- analysis, Ann. Fam. Med. 11 (5) (2013) 452-459. [16] P.A. Davis, W. Yokoyama, Cinnamon intake lowers fasting blood glucose: meta-analysis, J Med. Food. 14 (9) (2011) 884-889."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c57"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[17] M.J. Leach, S. Kumar, Cinnamon for diabetes mellitus, Cochrane. Database. Syst. Rev. 9 (2012) CD007170. [18] N. Namazi, K. Khodamoradi, S.P. Khamechi, J. Heshmati, M.H. Ayati, B. Larijani, The impact of cinnamon on anthropometric indices and glycemic status in patients with type 2 diabetes: A systematic review and meta-analysis of clinical trials, Complement Ther. Med. 43 (2019) 92-101. [19] P. Ranasinghe, R. Jayawardana, P. Galappaththy, G.R. Constantine, N. de Vas Gunawardana, P. Katulanda, Efficacy and safety of \"true\" cinnamon (Cinnamomum zeylanicum) as a pharmaceutical agent in diabetes: a systematic review and meta-analysis, Diabet. Med. 29 (12) (2012) 1480-1492. [20] R. Akilen, A. Tsiami, D. Devendra, N. Robinson, Cinnamon in glycaemic control: systematic review and meta analysis, Clin. Nutr. 31 (5) (2012) 609-615. [21] E.H. Kutbi, M.H. Sohouli, S. Fatahi, A. Lari, F. Shidfar, M.M. Aljhdali, et al., The beneficial effects of cinnamon among patients with metabolic diseases: A systematic review and dose-response meta-analysis of randomized-controlled trials, Crit. Rev. Food Sci. Nutr. 62 (22) (2022) 6113-6131."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c58"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[22] S. Deyno, K. Eneyew, S. Seyfe, N. Tuyiringire, E.L. Peter, R.A. Muluye, et al., Efficacy and safety of cinnamon in type 2 diabetes mellitus and pre-diabetes patients: A meta-analysis and meta-regression, Diabetes Res. Clin. Pract. 156 (2019) 107815. [23] N.A. ElSayed, G. Aleppo, V.R. Aroda, R.R. Bannuru, F.M. Brown, D. Bruemmer, et al., 2. Classification and diagnosis of diabetes. Standards of Care in Diabetes-2023, Diabetes Care 46 (Suppl 1) (2023) S19-S40. [24] R.J. Little, R. D\'Agostino, M.L. Cohen, K. Dickersin, S.S. Emerson, J.T. Farrar, et al., The prevention and treatment of missing data in clinical trials, N Engl. J Med. 367 (14) (2012) 1355-1360. [25] T.M. Wolever, The glycaemic index: a physiological classification of dietary carbohydrate, Cabi Publishing, 2006. [26] M.C. Gannon, F.Q. Nuttall, S.A. Westphal, B.J. Neil, E.R. Seaquist, Effects of dose of ingested glucose on plasma metabolite and hormone responses in type II diabetic subjects, Diabetes Care 12 (8) (1989) 544-552."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c59"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[27] H. Zelicha, A. Kaplan, A. Yaskolka Meir, G. Tsaban, E. Rinott, I. Shelef, et al., The effect of Wolffia globosa Mankai, a green aquatic plant, on postprandial glycemic response: A randomized crossover controlled trial, Diabetes Care 42 (7) (2019) 1162-1169. [28] [29] M. Matsuda, R.A. DeFronzo, Insulin sensitivity indices obtained from oral glucose tolerance testing: comparison with the euglycemic insulin clamp, Diabetes Care 22 (9) (1999) 1462-1470. T.J. Cleophas, A simple method for the estimation of interaction bias in crossover studies, J Clin. Pharmacol. 30 (11) (1990) 1036-1040. [30] J. Wang, S. Wang, J. Yang, S.M. Henning, Z. Ezzat-Zadeh, S.L. Woo, et al., Acute effects of cinnamon spice on ost-prandial glucose and insulin in normal weight and overweight/obese subjects: A pilot study, Front Nutr 7 (2020) 619782. [31] G.T.C. Ko, J.C. Chan, J. Woo, E. Lau, V.T. Yeung, C.C. Chow, et al., The reproducibility and usefulness of the oral glucose tolerance test in screening for diabetes and other cardiovascular risk factors, Ann. Clin. Biochem. 35 (1) (1998) 62-67."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c60"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[32] T. Danne, R. Nimri, T. Battelino, R.M. Bergenstal, K.L. Close, J.H. DeVries, et al., International consensus on use of continuous glucose monitoring, Diabetes Care 40 (12) (2017) 1631-1640. [33] U. Hoss, E.S. Budiman, Factory-calibrated continuous glucose sensors: the science behind the technology, Diabetes Technol. Ther. 19 (Suppl 2) (2017) S44-S50. [34] M. Bergman, M. Abdul-Ghani, R.A. DeFronzo, M. Manco, G. Sesti, T.V. Fiorentino, et al., Review of methods for detecting glycemic disorders, Diabetes Res. Clin. Pract. 165 (2020) 108233. [35] D. Rodbard, Glucose variability: a review of clinical applications and research developments, Diabetes Technol. Ther. 20 (S2) (2018) S25-S215. Suppl 2. [36] J.H. O\'Keefe, N.M. Gheewala, J.O. O\'Keefe, Dietary strategies for improving post-prandial glucose, lipids, inflammation, and cardiovascular health, J Am. Coll. Cardiol. 51 (3) (2008) 249-255. [37] J.H. O\'Keefe, D.S.H. Bell, Postprandial hyperglycemia/hyperlipidemia (postprandial dysmetabolism) is a cardiovascular risk factor, Am. J Cardiol. 100 (5) (2007) 899-904. [38] S. Bansal, J.E. Buring, N. Rifai, S. Mora, F.M. Sacks, P.M. Ridker, Fasting compared with nonfasting triglycerides and risk of cardiovascular events in women, JAMA 298 (3) (2007) 309-316."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c61"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[39] G.F. Lewis, K.D. Uffelman, L.W. Szeto, G. Steiner, Effects of acute hyperinsulinemia on VLDL triglyceride and VLDL apoB production in normal weight and obese individuals, Diabetes 42 (6) (1993) 833-842. [40] M. Adiels, S.O. Olofsson, M.R. Taskinen, J. Borén, Overproduction of very low-density lipoproteins is the hallmark of the dyslipidemia in the metabolic syndrome, Arterioscler. Thromb. Vasc. Biol. 28 (7) (2008) 1225-1236. [41] J. Jeppesen, C.B. Hollenbeck, M.Y. Zhou, A.M. Coulston, C. Jones, Y.D. Chen, et al., Relation between insulin resistance, hyperinsulinemia, postheparin plasma lipoprotein lipase activity, and postprandial lipemia, Arterioscler. Thromb. Vasc. Biol. 15 (3) (1995) 320-324. [42] A. Laatsch, M. Merkel, P.J. Talmud, T. Grewal, U. Beisiegel, J. Heeren, Insulin stimulates hepatic low density lipoprotein receptor-related protein 1 (LRP1) to increase postprandial lipoprotein clearance, Atherosclerosis 204 (1) (2009) 105-111. [43] T. Wang, X. Ma, T. Tang, K. Higuchi, D. Peng, R. Zhang, et al., The effect of glucose-dependent insulinotropic polypeptide (GIP) variants on visceral fat accumulation in Han Chinese populations, Nutr. Diabetes. 7 (5) (2017) e278."
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c62"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n[44] J.F. Gautier, S. Fetita, E. Sobngwi, C. Salaün-Martin, Biological actions of the incretins GIP and GLP-1 and therapeutic perspectives in patients with type 2 diabetes, Diabetes Metab 31 (3 Pt 1) (2005) 233-242. [45] T.P. Solomon, J.M. Haus, K.R. Kelly, M. Rocco, S.R. Kashyap, J.P. Kirwan, Improved pancreatic beta-cell function in type 2 diabetic patients after lifestyle- induced weight loss is related to glucose-dependent insulinotropic polypeptide, Diabetes Care 33 (7) (2010) 1561-1566. [46] W. Kim, J.M. Egan, The role of incretins in glucose homeostasis and diabetes treatment, Pharmacol. Rev. 60 (4) (2008) 470-512. [47] S.J. Kim, C. Nian, C.H.S. McIntosh, Activation of lipoprotein lipase by glucose-dependent insulinotropic polypeptide in adipocytes. A role for a protein kinase B, LKB1, and AMP-activated protein kinase cascade, J Biol. Chem. 282 (12) (2007) 8557-8567. 656"
#     page_span {
#       page_start: 8
#       page_end: 8
#     }
#     page_headers {
#       text: "H. Zelicha et al."
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#     page_headers {
#       text: "The American Journal of Clinical Nutrition 119 (2024) 649-657"
#       page_span {
#         page_start: 8
#         page_end: 8
#       }
#     }
#   }
#   chunks {
#     chunk_id: "c63"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n### H. Zelicha et al.\n\n[48] S.J. Kim, C. Nian, C.H.S. McIntosh, Resistin is a key mediator of glucose-dependent insulinotropic polypeptide (GIP) stimulation of lipoprotein lipase (LPL) activity in adipocytes, J Biol. Chem. 282 (47) (2007) 34139-34147. [49] G. Sikand, P. Kris-Etherton, N.M. Boulos, Impact of functional foods on prevention of cardiovascular disease and diabetes, Curr. Cardiol. Rep. 17 (6) (2015) 39. [50] P.V. Rao, S.H. Gan, Cinnamon: a multifaceted medicinal plant, Evid. Based Complement Alternat. Med. (2014) 642942. [51] R.A. Anderson, Chromium and polyphenols from cinnamon improve insulin sensitivity: plenary lecture, Proc. Nutr. Soc. 67 (1) (2008) 48-53. [52] Y. Wang, P.B. Harrington, P. Chen, Metabolomic profiling and comparison of major cinnamon species using UHPLC-HRMS, Anal. Bioanal. Chem. 412 (27) (2020) 7669-7681. [53] N.J. Hayward, G.J. McDougall, S. Farag, J.W. Allwood, C. Austin, F. Campbell, et al., Cinnamon shows antidiabetic properties that Are species- specific: effects on enzyme activity inhibition and starch digestion, Plant Foods Hum. Nutr. 74 (4) (2019) 544-552."
#     page_span {
#       page_start: 9
#       page_end: 9
#     }
#   }
#   chunks {
#     chunk_id: "c64"
#     content: "# Appendix A. Supplementary data\n\n## References\n\n### H. Zelicha et al.\n\n[54] M.L. Silva, M.A. Bernardo, J. Singh, M.F. de Mesquita, Cinnamon as a complementary therapeutic approach for dysglycemia and dyslipidemia control in type 2 diabetes mellitus and its molecular mechanism of action: a review, Nutrients 14 (13) (2022) 2773. [55] Q.Y. Lu, P.H. Summanen, R.P. Lee, J. Huang, S.M. Henning, D. Heber, et al., Prebiotic potential and chemical composition of seven culinary spice extracts, J Food Sci 82 (8) (2017) 1807-1813. [56] Q.Y. Lu, A.M. Rasmussen, J. Yang, R.P. Lee, J. Huang, P. Shao, et al., Mixed spices at culinary doses have prebiotic effects in healthy adults: A pilot study, Nutrients 11 (6) (2019)."
#     page_span {
#       page_start: 9
#       page_end: 9
#     }
#   }
#   chunks {
#     chunk_id: "c65"
#     content: "# Appendix A. Supplementary data\n\n## The American Journal of Clinical Nutrition 119 (2024) 649-657\n\n[57] H. Wang, W. Song, W. Yuan, Q. Zhou, F.A. Sadiq, J. Zhao, et al., Modulating the human gut microbiota through hypocaloric balanced diets: an effective approach for managing obesity, Nutrients 15 (14) (2023). [58] E. Barengolts, S.J. Green, Y. Eisenberg, A. Akbar, B. Reddivari, B.T. Layden, et al., Gut microbiota varies by opioid use, circulating leptin and oxytocin in African American men with diabetes and high burden of chronic disease, PLOS ΟΝΕ 13 (3) (2018) e0194171. [59] R.J. Basseri, B. Basseri, M. Pimentel, K. Chong, A. Youdim, K. Low, et al., Intestinal methane production in obese individuals is associated with a higher body mass index, Gastroenterol Hepatol (NY). 8 (1) (2012) 22-28. [60] P. Kawatra, R. Rajagopalan, Cinnamon: mystic powers of a minute ingredient, Pharmacognosy Res 7 (Suppl 1) (2015) S1-S6. [61] P. Chen, J. Sun, P. Ford, Differentiation of the four major species of cinnamons (C. burmannii, C. verum, C. cassia, and C. loureiroi) using a flow injection mass spectrometric (FIMS) fingerprinting method, J Agric. Food Chem. 62 (12) (2014) 2516-2521. [62] [63]"
#     page_span {
#       page_start: 9
#       page_end: 9
#     }
#   }
#   chunks {
#     chunk_id: "c66"
#     content: "# Appendix A. Supplementary data\n\n## The American Journal of Clinical Nutrition 119 (2024) 649-657\n\nB.E. Al-Dhubiab, Pharmaceutical applications and phytochemical profile of Cinnamomum burmannii, Pharmacogn. Rev. 6 (12) (2012) 125-131. K. Abraham, F. Wöhrlin, O. Lindtner, G. Heinemeyer, A. Lampen, Toxicology and risk assessment of coumarin: focus on human data, Mol. Nutr. Food Res. 54 (2) (2010) 228-239. [64] N. Iwata, M. Kainuma, D. Kobayashi, T. Kubota, N. Sugawara, A. Uchida, et al., The relation between hepatotoxicity and the total coumarin intake from traditional Japanese medicines containing cinnamon bark, Front Pharmacol 7 (2016) 174. [65] Coumarin in flavourings and other food ingredients with flavouring properties- Scientific Opinion of the Panel on Food Additives, Flavourings, Processing Aids and Materials in Contact with Food (AFC), EFSA J (2008) 793. 657"
#     page_span {
#       page_start: 9
#       page_end: 9
#     }
#   }
# }

# %% [markdown]
# ### Notes on tokens and chunks
#
# #### Tokens
#
# LLMs generally work with `tokens` rather than words. When dealing with text, a token often represents subsections of words, and tokenization can be done in different ways, such as breaking text up by characters, or using subword-based tokenization (e.g., the word "unbelievable" could be split into subwords such as "un", "believe", "able").
#
# The exact size and definition of a token can vary based on different tokenization methods, models, languages, and other factors, but a general rule of thumb for English text using subword tokenizers is around 4 characters per token on average.
#
# #### Chunks
#
# When creating embeddings, we usually break a document into chunks and then create embeddings of those chunks. Again, this can be done in different ways, using different tools. In this notebook, we're using Google Cloud Document AI to break our documents into chunks.
#
# For this purpose, one of the parameters we need to specify for our Document AI Processor is the `chunkSize` to use, which is measured (in this case) by number of tokens per chunk. You may need to experiment with the value for this parameter to find the chunk size that works best for your use case (e.g., based on the length and structure of the document sections). You generally want your chunks to capture some level of semantic granularity, but there are trade-offs in terms of this granularity. For example, smaller chunks can capture more granular sematic context, and can provide more precise search results, but can be less efficient (computationally) to process. You also need to ensure chunks sizes are within the input length limits of the embedding model you're using in order to avoid possible truncation.
#
# A good practice is to start with a moderate chunk size and adjust it based on how well it fits your needs.
#
# Fortunately, Document AI can automatically handle some chunking based on layout, even without a set chunkSize, so that can be helpful if you don't know what chunk size to use.

# %% [markdown]
# ### Review document layout and chunks
#
# #### Print sample of document layout
#
# The following code will print the first couple of blocks from our document layout.

# %%
print(doc_layout.blocks[:2])
# Out:
# [block_id: "1"
# text_block {
#   text: "ASN"
#   type_: "paragraph"
# }
# page_span {
#   page_start: 1
#   page_end: 1
# }
# , block_id: "2"
# text_block {
#   text: "EST. 1928"
#   type_: "paragraph"
# }
# page_span {
#   page_start: 1
#   page_end: 1
# }
# ]

# %% [markdown]
# ### Review the text chunks
#
# The following code will consolidate our document chunks into a list that we can use from here onwards.
#
# We will also print the first 5 chunks to see their contents.

# %%
text_chunks = [chunk.content for chunk in chunked_doc.chunks]

# %%
print(text_chunks[:5])
# Out:
# ['ASN EST. 1928 American Society for Nutrition Excellence in Nutrition Research and Practice The American Journal of Clinical Nutrition 119 (2024) 649-657 The American Journal of CLINICAL NUTRITION journal homepage: https://ajcn.nutrition.org/ The merican Journal CLINICAL NUTRITION Original Research Article', '# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\nHila Zelicha¹, Jieping Yang 2, Susanne M Henning 2, Jianjun Huang 2, Ru-Po Lee2, Gail Thames 2, Edward H Livingston¹, David Heber², Zhaoping Li 2,* Department of Surgery, University of California, Los Angeles, Los Angeles, CA, United States; 2 Department of Medicine, Center for Human Nutrition, David Geffen School of Medicine, Los Angeles, United States', '# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\n## ABSTRACT\n\nCheck for updates Background: Previous clinical studies showing that cinnamon spice lowers blood glucose concentrations had inconsistent results. Objectives: To determine the effect of daily cinnamon spice supplementation in an amount commonly used for seasoning on glucose concentrations in adults with obesity and prediabetes. Methods: Following a 2-wk run-in period of maintaining a low polyphenol/fiber diet, 18 participants with obesity and prediabetes underwent a 10-wk randomized, controlled, double-blind, crossover trial (mean age 51.1 y; mean fasting plasma glucose 102.9~mg/dL). The participants were randomly assigned to take cinnamon (4~g/d) or placebo for 4-wk, followed by a 2-wk washout period, and then crossed over to the other intervention for an additional 4-wk. Glucose changes were measured with continuous glucose monitoring. Oral glucose tolerance testing immediately following ingestion of cinnamon or placebo was performed at 4-time points to assess their acute effects both at the baseline and end of each intervention phase. Digestive symptom logs were obtained daily.', '# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\n## ABSTRACT\n\nResults: There were 694 follow-up days with 66,624 glucose observations. When compared with placebo, 24-h glucose concentrations were significantly lower when cinnamon was administered [mixed-models; effect size (ES) = 0.96; 95% confidence interval (CI): -2.9, -1.5; P<0.0017. Similarly, the mean net-area-under-the-curve (netAUC) for glucose was significantly lower than for placebo when cinnamon was given (over 24 h; ES=-0.66:95\\% CI: 2501.7, 5412.1, P=0.01). Cinnamon supplementation resulted in lower glucose peaks compared with placebo (Apeak 9.56\\pm9.1~mg/dI compared with 11.73\\pm8.0~mg/dL; ES = -0.57; 95% CI: 0.8, 3.7, P=0.027). Glucose-dependent-insulinotropic-polypeptide concentrations increased during oral glucose tolerance testing + cinnamon testing (mixed-models; ES = 0.51; 95% CI: 1.56, 100.1, P=0.04, whereas triglyceride concentrations decreased (mixed-models; ES=0.55; 95% CI: -16.0, -1.6, P=0.02. Treatment adherence was excellent in both groups (cinnamon: 97.6\\pm3.4\\% compared with placebo: 979+37\\%; ES=-0.15. 95% CI: -1.8, 0.2, P=0.5. No differences were found in digestive symptoms (abdominal pain, borborygmi, bloating, excess flatus, and stools/day) between cinnamon and placebo groups.', '# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\n## ABSTRACT\n\nConclusions: Cinnamon, a widely available and low-cost supplement, may contribute to better glucose control when added to the diet in people who have obesity-related prediabetes. This trial was registered at clinicaltrials.gov as NCT04342624. Keywords: cinnamon, continuous glucose system, glycemic response, polyphenols, prediabetes']

# %% [markdown]
# ## Create embeddings
#
# Now that we have broken our document down into chunks, the next steps is to get embeddings for our chunks.
#
# We will use the `textembedding-gecko` model to create our embeddings (see [documentation here](https://cloud.google.com/vertex-ai/generative-ai/docs/model-reference/text-embeddings) for more details).

# %%
from typing import List

from vertexai.language_models import TextEmbeddingInput, TextEmbeddingModel

def embed_text(
    texts: List[str] = text_chunks,  # Use your extracted chunks
    task: str = "RETRIEVAL_DOCUMENT",
    model_name: str = "textembedding-gecko@003",
) -> List[List[float]]:
    model = TextEmbeddingModel.from_pretrained(model_name)
    inputs = [TextEmbeddingInput(text, task) for text in texts]
    embeddings = model.get_embeddings(inputs)
    return [embedding.values for embedding in embeddings]

embeddings = embed_text(text_chunks)

# %% [markdown]
# ### Save embeddings
#
# Next, we will save our embeddings in a local file.
#
# The code in the following cell will also save the text chunks with their associated embeddings, which we can use for retrieval later.
#
# This file will be used as input when creating a Vertex AI Vector Search index in subsequent sections of this notebook.
#
# See the documentation [here](https://cloud.google.com/vertex-ai/docs/vector-search/setup/format-structure) for requirements regarding the input format structure for Vertex AI Vector Search indexes.

# %%
import json
filename = f"embeddings-{UID}.json"

def create_embeddings_jsonl(text_chunks, embeddings, filename):
    with open(filename, 'w') as outfile:
        for idx, (text, embedding) in enumerate(zip(text_chunks, embeddings)):
            data = {
                "id": idx,
                "text": text,
                "embedding": embedding
            }
            json.dump(data, outfile, separators=(',', ':'))
            outfile.write('\n')

create_embeddings_jsonl(text_chunks, embeddings, filename)

# %% [markdown]
# ### Upload file to GCS
#
# Next, we will upload our file to Google Cloud Storage (GCS). This is required for us to ingest our embeddings into Vertex AI Vector Search.

# %%
embeddings_path = f"gs://{BUCKET}/chapter-18-embeddings-data-{UID}/batch_root/"

# %%
# !gsutil cp {filename} {embeddings_path}
# Out:
# 831.23s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Copying file://embeddings-01201941.json [Content-Type=application/json]...
# \ [1 files][  1.1 MiB/  1.1 MiB]
# Operation completed over 1 objects/1.1 MiB.

# %% [markdown]
# ## Create Vertex AI Vector Search Index
#
# We will store our embeddings in Vertex AI Vector Search. To do that we need to create an index and specify the GCS location of our embeddings file to be ingested.
#
# See the documentation [here](https://cloud.google.com/vertex-ai/docs/vector-search/create-manage-index) and [here](https://cloud.google.com/vertex-ai/docs/vector-search/configuring-indexes) for more details on creating Index and the parameters.

# %% [markdown]
# ### First, get the embedding dimensionality
#
# When creating an index in Vertex AI Vector Search, we need to know the dimensionality of our embeddings. We can get that with the following code.

# %%
first_embedding = embeddings[0] # Assumes all our embeddings have same dimensionality, so we can just use the first one.
embeddings_dimensionality = len(first_embedding) 
print(f"Embeddings dimensionality: {embeddings_dimensionality}")
# Out:
# Embeddings dimensionality: 768

# %% [markdown]
# ### Create the index
#
# This process can take a long time, depending on the amount of embeddings.

# %%
from google.cloud import aiplatform

def vector_search_create_index(
    project: str, location: str, display_name: str, gcs_uri: Optional[str] = None
) -> None:
    # Initialize the Vertex AI client
    aiplatform.init(project=project, location=location, staging_bucket=BUCKET)

    # Create Index
    index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
        display_name=display_name,
        contents_delta_uri=f"{embeddings_path}",
        description="RAG Index",
        dimensions=embeddings_dimensionality,
        approximate_neighbors_count=50,
        leaf_node_embedding_count=500,
        leaf_nodes_to_search_percent=7,
        index_update_method="batch_update",  
        distance_measure_type="DOT_PRODUCT_DISTANCE",
    )
    return(index)

location = "us-central1"
display_name = f"RAG-index-{UID}"
vvs_index = vector_search_create_index(PROJECT_ID, location, display_name)
# Out:
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/714662258896/locations/us-central1/indexes/7631309986160705536/operations/2752643749732417536
# MatchingEngineIndex created. Resource name: projects/714662258896/locations/us-central1/indexes/7631309986160705536
# To use this MatchingEngineIndex in another session:
# index = aiplatform.MatchingEngineIndex('projects/714662258896/locations/us-central1/indexes/7631309986160705536')

# %% [markdown]
# ## Create Endpoint and Deploy Index
#
# To use our index, we need to deploy it to an endpoint.

# %% [markdown]
# ### First, create the endpoint

# %%
## create `IndexEndpoint`
vvs_index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
    display_name = f"index-endpoint-{UID}",
    public_endpoint_enabled = True
)
# Out:
# Creating MatchingEngineIndexEndpoint
# Create MatchingEngineIndexEndpoint backing LRO: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680/operations/7650308344497831936
# MatchingEngineIndexEndpoint created. Resource name: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# To use this MatchingEngineIndexEndpoint in another session:
# index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680')

# %% [markdown]
# ### Deploy the index to the endpoint
#
# **This step can take a long time.**
#
# To check the status in the Google Cloud console, navigate to Vertex AI -> Vector Search, and click on the name of your index.

# %%
# Create an ID for the index
DEPLOYED_INDEX_ID = f"deployed_index_{UID}"

vvs_index_endpoint.deploy_index(
    index = vvs_index, deployed_index_id = DEPLOYED_INDEX_ID
)
# Out:
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680/operations/2588825313286815744
# MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# <google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint.MatchingEngineIndexEndpoint object at 0x139e34910>
# resource name: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680

# %% [markdown]
# ## Perform a vector-based similarity search
#
# Now that we have created our index, we can use it to perform a vector-based similarity search to find the nearest neighbors to our query.
#
# For this work, we need to first create an embedding of our query using the same model that was used to create embeddings for our text chunks earlier (in our case, we used `textembedding-gecko@003`). This is done using the `embed_query` function.
#
# Let's use one of our questions from Chapter 16 (feel free to replace the `query_text` string with other questions related to the document contents).

# %%
# Create embedding for input query
def embed_query(text: str, task: str = "RETRIEVAL_DOCUMENT", model_name: str = "textembedding-gecko@003"):
    model = TextEmbeddingModel.from_pretrained(model_name)
    input = TextEmbeddingInput(text, task)  # Create a single input object
    embeddings = model.get_embeddings([input])  # Pass input as a list
    return embeddings[0].values  # Return the embedding as a list of floats

query_text = "How might cinnamon supplementation interact with other dietary or lifestyle interventions for prediabetes management?"
query_embedding = embed_query(query_text)

# Find the nearest neighbors
response = vvs_index_endpoint.find_neighbors(
    deployed_index_id=DEPLOYED_INDEX_ID,
    queries=[query_embedding],
    num_neighbors=3 # You can change this value to return more or fewer neighbors
)

# %% [markdown]
# ### Print details of all of the nearest neighbors returned
#
# In the response, we can see the details of the nearest neighbors returned, including their IDs and distances relative to our query.
#
# Usually, smaller distance means that the returned neighbors are more similar to our query (e.g., Euclidean distance). However, we are using the `DOT_PRODUCT_DISTANCE`, which means that, counter-intuitively, the higher the value of the `distance` metric, the closer and more similar the returned neighbor is to our query.

# %%
print(response)
# Out:
# [[MatchNeighbor(id='25', distance=0.8742802143096924, sparse_distance=None, feature_vector=[], crowding_tag='0', restricts=[], numeric_restricts=[], sparse_embedding_values=[], sparse_embedding_dimensions=[]), MatchNeighbor(id='1', distance=0.8691182136535645, sparse_distance=None, feature_vector=[], crowding_tag='0', restricts=[], numeric_restricts=[], sparse_embedding_values=[], sparse_embedding_dimensions=[]), MatchNeighbor(id='63', distance=0.8643720149993896, sparse_distance=None, feature_vector=[], crowding_tag='0', restricts=[], numeric_restricts=[], sparse_embedding_values=[], sparse_embedding_dimensions=[])]]

# %% [markdown]
# ### Print details of the nearest neighbor returned

# %%
print(response[0][0])
# Out:
# MatchNeighbor(id='25', distance=0.8742802143096924, sparse_distance=None, feature_vector=[], crowding_tag='0', restricts=[], numeric_restricts=[], sparse_embedding_values=[], sparse_embedding_dimensions=[])

# %% [markdown]
# ### Inspect the nearest neighbor
#
# The following code will display the nearest neighbor embedding.

# %%
neighbor_id = response[0][0].id
neighbor_embedding = vvs_index_endpoint.read_index_datapoints(deployed_index_id=DEPLOYED_INDEX_ID, ids= [neighbor_id],)
print(neighbor_embedding)
# Out:
# [datapoint_id: "25"
# feature_vector: 0.014373892
# feature_vector: -0.0427189767
# feature_vector: -0.0532056801
# feature_vector: -0.00436879508
# feature_vector: 0.0825413391
# feature_vector: 0.0304773413
# feature_vector: 0.0034575921
# feature_vector: 0.00373135903
# feature_vector: -0.0143200643
# feature_vector: 0.0178219397
# feature_vector: 0.00431234064
# feature_vector: 0.00732157705
# feature_vector: -0.0478230305
# feature_vector: 0.0167984422
# feature_vector: 0.0192254838
# feature_vector: 0.0113015203
# feature_vector: 0.047644943
# feature_vector: 0.0298034884
# feature_vector: -0.0135832513
# feature_vector: -0.00662099896
# feature_vector: 0.0396740697
# feature_vector: 0.0407610089
# feature_vector: -0.00348951062
# feature_vector: -0.00642215274
# feature_vector: 0.0196758341
# feature_vector: -0.000217798166
# feature_vector: -0.00343293673
# feature_vector: -0.0785962641
# feature_vector: -0.0765778869
# feature_vector: 0.0191346817
# feature_vector: -0.024271192
# feature_vector: 0.0148314871
# feature_vector: -0.0587520115
# feature_vector: -0.0164805129
# feature_vector: -0.025009729
# feature_vector: -0.0353346765
# feature_vector: -0.0138647463
# feature_vector: -0.0383392908
# feature_vector: 0.0248078834
# feature_vector: 0.0430030376
# feature_vector: -0.00119303761
# feature_vector: -0.0125298863
# feature_vector: -0.0762973055
# feature_vector: -0.0376419276
# feature_vector: 0.0168201923
# feature_vector: -0.0260990486
# feature_vector: 0.00718367891
# feature_vector: 0.0457964204
# feature_vector: 0.0186929815
# feature_vector: -0.00146647554
# feature_vector: 0.0114322221
# feature_vector: 0.0427492633
# feature_vector: 0.0656727
# feature_vector: -0.00191072188
# feature_vector: -0.0271204785
# feature_vector: -0.0340115167
# feature_vector: 0.0451343209
# feature_vector: -0.00860033464
# feature_vector: -0.0246143639
# feature_vector: 0.020115748
# feature_vector: 0.0255671963
# feature_vector: 0.0308105573
# feature_vector: -0.0040348568
# feature_vector: -0.00936240144
# feature_vector: -0.00288161589
# feature_vector: -0.0776034594
# feature_vector: -0.0314896069
# feature_vector: -0.000293814694
# feature_vector: 0.107333481
# feature_vector: -0.0349392816
# feature_vector: 0.00524837
# feature_vector: -0.0187542774
# feature_vector: 0.0257205963
# feature_vector: -0.00175898813
# feature_vector: -0.0537325703
# feature_vector: -0.109701656
# feature_vector: 0.0102599822
# feature_vector: 0.0580292121
# feature_vector: 0.0373930521
# feature_vector: 0.0317230038
# feature_vector: 0.00505269365
# feature_vector: -0.000888067181
# feature_vector: -0.0480625629
# feature_vector: -0.0161798038
# feature_vector: -0.0639472455
# feature_vector: 0.0200199876
# feature_vector: -0.0473015271
# feature_vector: 0.00271346
# feature_vector: 0.0398324803
# feature_vector: 0.0493932962
# feature_vector: -0.0124322521
# feature_vector: -0.0649657771
# feature_vector: 0.0551622882
# feature_vector: -0.0729968697
# feature_vector: -0.0341526717
# feature_vector: 0.03131162
# feature_vector: -0.0288824067
# feature_vector: -0.036154896
# feature_vector: 0.0316933133
# feature_vector: -0.0417376
# feature_vector: -0.00346313743
# feature_vector: -0.00224478496
# feature_vector: -0.0584139302
# feature_vector: 0.0355754308
# feature_vector: 0.0465175323
# feature_vector: 0.0512024052
# feature_vector: 0.0114460606
# feature_vector: 0.0451121554
# feature_vector: -0.0056322543
# feature_vector: 0.0349376537
# feature_vector: -0.0599373579
# feature_vector: -0.0301037971
# feature_vector: 0.0250644032
# feature_vector: -0.00921814
# feature_vector: 0.0183666646
# feature_vector: -0.0213957448
# feature_vector: -0.007643627
# feature_vector: 0.0587716065
# feature_vector: 0.000960688165
# feature_vector: 0.00739841862
# feature_vector: 0.0214988589
# feature_vector: -0.00253746728
# feature_vector: 0.0837614164
# feature_vector: 0.0368950814
# feature_vector: 0.0223349389
# feature_vector: 0.00942381471
# feature_vector: 0.0292613618
# feature_vector: 0.0566453449
# feature_vector: 0.0451274216
# feature_vector: -0.0263366327
# feature_vector: 0.000500401948
# feature_vector: -0.0379640535
# feature_vector: -0.0375784598
# feature_vector: -0.00329024834
# feature_vector: 0.0368307456
# feature_vector: 0.030386433
# feature_vector: 0.0398279056
# feature_vector: 0.0125911627
# feature_vector: 0.0642422512
# feature_vector: -0.00876727328
# feature_vector: 0.0270707533
# feature_vector: 0.0263619814
# feature_vector: 0.0214998629
# feature_vector: 0.0543155782
# feature_vector: -0.0110514583
# feature_vector: 0.0539024174
# feature_vector: -0.0533749349
# feature_vector: 0.00275448593
# feature_vector: 0.0367051251
# feature_vector: -0.0157702584
# feature_vector: 0.00796372
# feature_vector: 0.0144127468
# feature_vector: -0.0783189
# feature_vector: -0.00754963793
# feature_vector: 0.0637867525
# feature_vector: 0.00167613954
# feature_vector: -0.052750092
# feature_vector: 0.0027441876
# feature_vector: 0.00573752401
# feature_vector: 0.00152923854
# feature_vector: 0.0209247973
# feature_vector: -0.0280514751
# feature_vector: 0.0608811677
# feature_vector: 0.0040548807
# feature_vector: 0.00589245791
# feature_vector: -0.0378549732
# feature_vector: 0.0419404134
# feature_vector: 0.0142385885
# feature_vector: -0.0174576901
# feature_vector: -0.0218876265
# feature_vector: -0.0082422616
# feature_vector: 0.0435262583
# feature_vector: -0.022516638
# feature_vector: -0.0128195863
# feature_vector: 0.00367570785
# feature_vector: -0.0454893596
# feature_vector: 0.0171095356
# feature_vector: 0.0118548693
# feature_vector: -0.0408203527
# feature_vector: -0.020990748
# feature_vector: 0.021001948
# feature_vector: -0.0108845634
# feature_vector: 0.0121545717
# feature_vector: 0.0513024107
# feature_vector: -0.0264792144
# feature_vector: -0.0138575826
# feature_vector: 0.0292155501
# feature_vector: 0.0110505223
# feature_vector: -0.0114924507
# feature_vector: -0.0177180301
# feature_vector: 0.0180272106
# feature_vector: 0.0151291694
# feature_vector: -0.0489441343
# feature_vector: -0.0364660509
# feature_vector: -0.00448573707
# feature_vector: 0.059267696
# feature_vector: -0.00760684116
# feature_vector: 0.0202065203
# feature_vector: -0.0225068573
# feature_vector: -0.0403975025
# feature_vector: -0.0203603189
# feature_vector: 0.0771651939
# feature_vector: 0.00977141596
# feature_vector: 0.010978464
# feature_vector: 0.0229211226
# feature_vector: -0.0384634547
# feature_vector: 0.0709248856
# feature_vector: -0.0278845485
# feature_vector: -0.027132852
# feature_vector: 0.0423037075
# feature_vector: -0.0480545461
# feature_vector: 0.0438772924
# feature_vector: -0.0162549485
# feature_vector: 0.0544870086
# feature_vector: 0.0457922257
# feature_vector: -0.00941938441
# feature_vector: -0.0456575081
# feature_vector: -0.0266786255
# feature_vector: 0.017117966
# feature_vector: -0.0328507088
# feature_vector: 0.00857162662
# feature_vector: 0.0246509239
# feature_vector: -0.0283298101
# feature_vector: 0.0221231692
# feature_vector: 0.0176758
# feature_vector: 0.0726362541
# feature_vector: 0.0235462617
# feature_vector: 0.0216064472
# feature_vector: 0.0238711964
# feature_vector: -0.0208884552
# feature_vector: 0.0342629552
# feature_vector: 0.111057051
# feature_vector: 0.0450983644
# feature_vector: 0.0207318682
# feature_vector: 0.0363789611
# feature_vector: 0.0130672641
# feature_vector: 0.0190156754
# feature_vector: 0.0153968055
# feature_vector: 0.0354106054
# feature_vector: 0.0142443655
# feature_vector: -0.0558540076
# feature_vector: 0.0439048484
# feature_vector: 0.0487579964
# feature_vector: 0.0362156406
# feature_vector: 0.00664497772
# feature_vector: -0.0548629202
# feature_vector: -0.0500473715
# feature_vector: 0.109794609
# feature_vector: -0.0105517441
# feature_vector: 0.0199516695
# feature_vector: -0.0118653895
# feature_vector: -0.0448110811
# feature_vector: 0.00432642782
# feature_vector: 0.00677427324
# feature_vector: -0.0623031929
# feature_vector: 0.0484770238
# feature_vector: -0.0442310087
# feature_vector: 0.0135869589
# feature_vector: -0.0724975839
# feature_vector: 0.0100599257
# feature_vector: 0.062581338
# feature_vector: -0.0482715741
# feature_vector: 0.00156279816
# feature_vector: 0.0443104915
# feature_vector: -0.0481497422
# feature_vector: -0.0124230413
# feature_vector: 0.0156393945
# feature_vector: -0.026397014
# feature_vector: 0.00401083333
# feature_vector: 0.0639291331
# feature_vector: 0.0507618524
# feature_vector: -0.0387837067
# feature_vector: 0.059641961
# feature_vector: 0.0102296807
# feature_vector: -0.0288184602
# feature_vector: 0.0293434206
# feature_vector: 0.00680181338
# feature_vector: 0.0290242732
# feature_vector: 0.0219476428
# feature_vector: -0.012224487
# feature_vector: -0.0157863535
# feature_vector: -0.0167091805
# feature_vector: 0.0426582322
# feature_vector: -0.0656716
# feature_vector: -0.0136786923
# feature_vector: 0.0201861467
# feature_vector: -0.0229006745
# feature_vector: -0.0113158301
# feature_vector: 0.0112123964
# feature_vector: -0.0375980325
# feature_vector: -0.0440423116
# feature_vector: -0.0299141575
# feature_vector: 0.0246658567
# feature_vector: -0.0417725965
# feature_vector: -0.019334659
# feature_vector: 0.0155087393
# feature_vector: -0.00589992106
# feature_vector: 0.0348100774
# feature_vector: 0.0359273031
# feature_vector: -0.0189330559
# feature_vector: -0.000341946434
# feature_vector: -0.0717571378
# feature_vector: -0.00119745499
# feature_vector: -0.0295586921
# feature_vector: -0.000491367071
# feature_vector: -0.0229576491
# feature_vector: -0.0083006965
# feature_vector: -0.0179414302
# feature_vector: -0.00717490865
# feature_vector: -0.00198220694
# feature_vector: -0.0104418145
# feature_vector: -0.0104586156
# feature_vector: -0.0098705776
# feature_vector: 0.0169938542
# feature_vector: 0.024858389
# feature_vector: 0.0287460387
# feature_vector: -0.0563467257
# feature_vector: 0.0361655019
# feature_vector: -0.0354332961
# feature_vector: 0.0471254773
# feature_vector: -0.0222879704
# feature_vector: 0.0885020718
# feature_vector: 0.0377611518
# feature_vector: -0.0167301763
# feature_vector: 0.0192000959
# feature_vector: 0.0271899812
# feature_vector: -0.0361118205
# feature_vector: -0.0437593237
# feature_vector: -0.0368492231
# feature_vector: -0.0112466067
# feature_vector: -0.029952541
# feature_vector: 0.0247925185
# feature_vector: 0.0241606757
# feature_vector: -0.00101311796
# feature_vector: -0.000565046968
# feature_vector: 0.0393232964
# feature_vector: -0.0369649976
# feature_vector: -0.0257766917
# feature_vector: 0.00274576526
# feature_vector: -0.0293949824
# feature_vector: 0.0537508056
# feature_vector: 0.00183341012
# feature_vector: -0.0297779553
# feature_vector: 0.0181904938
# feature_vector: 0.00393245555
# feature_vector: 0.00426562456
# feature_vector: -0.0470150635
# feature_vector: 0.0316455588
# feature_vector: 0.0800537467
# feature_vector: 0.0832196623
# feature_vector: -0.029919723
# feature_vector: 0.0511873327
# feature_vector: -0.0431143641
# feature_vector: -0.0342002474
# feature_vector: -0.00975013711
# feature_vector: -0.0391387492
# feature_vector: 0.0636147112
# feature_vector: -0.00245514303
# feature_vector: 0.0300033353
# feature_vector: -0.0180056505
# feature_vector: 0.0191724021
# feature_vector: 0.0106122708
# feature_vector: 0.0136512462
# feature_vector: 0.0248064119
# feature_vector: 0.00443247054
# feature_vector: -0.0481326878
# feature_vector: -0.00771140307
# feature_vector: 0.0299354047
# feature_vector: -0.0487578027
# feature_vector: 0.0454443693
# feature_vector: 0.0328097828
# feature_vector: -0.0155805033
# feature_vector: 0.0214382503
# feature_vector: -0.0416365042
# feature_vector: 0.0317934118
# feature_vector: 0.0328274816
# feature_vector: -0.0177088566
# feature_vector: -0.0471993908
# feature_vector: -0.00359662739
# feature_vector: -0.0204579625
# feature_vector: 0.01165633
# feature_vector: 0.000740787655
# feature_vector: 0.0634739622
# feature_vector: 0.0267154146
# feature_vector: -0.0161073655
# feature_vector: -0.0379960202
# feature_vector: 0.0326087102
# feature_vector: 0.0422688462
# feature_vector: -0.0353340507
# feature_vector: 0.0402118713
# feature_vector: -0.0122570889
# feature_vector: 0.0255208854
# feature_vector: 0.100190215
# feature_vector: 0.00195915555
# feature_vector: 0.0367045626
# feature_vector: -0.0274854135
# feature_vector: 0.014840574
# feature_vector: -0.0129876174
# feature_vector: -0.000373176561
# feature_vector: -0.0181722194
# feature_vector: -0.0109656285
# feature_vector: -0.0822711
# feature_vector: -0.0291997492
# feature_vector: -0.0147426901
# feature_vector: -0.0434649065
# feature_vector: 0.0161554366
# feature_vector: -0.0266964212
# feature_vector: -0.0176193174
# feature_vector: -0.00207711151
# feature_vector: 0.016074596
# feature_vector: -0.00864504836
# feature_vector: -0.0186852831
# feature_vector: -0.00862904079
# feature_vector: -0.0219621658
# feature_vector: -0.0511957109
# feature_vector: -0.0142287472
# feature_vector: 0.0524836704
# feature_vector: 0.00301466463
# feature_vector: 0.0145574166
# feature_vector: 0.0338883772
# feature_vector: 0.000488169753
# feature_vector: -0.00192119332
# feature_vector: 0.0589520819
# feature_vector: -0.00375080248
# feature_vector: -0.023542745
# feature_vector: -0.0893300697
# feature_vector: 0.0301673934
# feature_vector: 0.00480705779
# feature_vector: 0.00725602
# feature_vector: 0.0355463028
# feature_vector: 0.00916282274
# feature_vector: -0.0131705916
# feature_vector: -0.0365356095
# feature_vector: -0.0209754631
# feature_vector: -0.00394126
# feature_vector: -0.02618948
# feature_vector: -0.0224073753
# feature_vector: 0.0191089064
# feature_vector: -0.0365605168
# feature_vector: -0.0177724939
# feature_vector: 0.0186736621
# feature_vector: -0.00938503165
# feature_vector: 0.0530994423
# feature_vector: -0.0330721922
# feature_vector: -0.00759875216
# feature_vector: -0.0118201822
# feature_vector: -0.0225872211
# feature_vector: -0.00950439461
# feature_vector: 0.0106173353
# feature_vector: -0.111886308
# feature_vector: 0.0545124151
# feature_vector: -0.0623477288
# feature_vector: -0.0239902
# feature_vector: -0.0634838194
# feature_vector: -0.0298676826
# feature_vector: -0.0434140041
# feature_vector: -0.0254349969
# feature_vector: 0.0378989689
# feature_vector: 0.0395311825
# feature_vector: 0.0261737183
# feature_vector: 0.0261113308
# feature_vector: -0.0385632925
# feature_vector: 0.0506704748
# feature_vector: -0.0494979322
# feature_vector: 0.0342204124
# feature_vector: -0.0358957611
# feature_vector: -0.0168253127
# feature_vector: -0.00801385
# feature_vector: -0.0502571799
# feature_vector: 0.024588367
# feature_vector: -0.0423060358
# feature_vector: -0.0212705825
# feature_vector: -0.00778371515
# feature_vector: 0.0300103035
# feature_vector: -0.0809321702
# feature_vector: 0.00851787068
# feature_vector: -0.0793725252
# feature_vector: 0.0709370077
# feature_vector: -0.044688493
# feature_vector: -0.010094841
# feature_vector: 0.0382514261
# feature_vector: 0.0220367275
# feature_vector: 0.0340644196
# feature_vector: 0.0160690658
# feature_vector: -0.0292441808
# feature_vector: 0.0477821603
# feature_vector: -0.00524952495
# feature_vector: -0.0231489874
# feature_vector: -0.0612443052
# feature_vector: 0.0429925285
# feature_vector: -0.00905918516
# feature_vector: -0.0219717864
# feature_vector: -0.00617297878
# feature_vector: -0.0146074174
# feature_vector: -0.0140492152
# feature_vector: 0.0212322902
# feature_vector: -0.0298278257
# feature_vector: 0.0810985938
# feature_vector: 0.0247796625
# feature_vector: -0.00301280525
# feature_vector: 0.0129477624
# feature_vector: -0.00496716285
# feature_vector: 0.0266046152
# feature_vector: 0.0233953986
# feature_vector: 0.0444279872
# feature_vector: -0.0460189655
# feature_vector: 0.0358735174
# feature_vector: 0.0415364355
# feature_vector: -0.0155743435
# feature_vector: 0.0154741006
# feature_vector: 0.00959795248
# feature_vector: 0.00157351838
# feature_vector: 0.0580941029
# feature_vector: 0.0204654522
# feature_vector: 0.0288337637
# feature_vector: 0.0181213021
# feature_vector: 0.0116206594
# feature_vector: 0.00257427478
# feature_vector: -0.0182031021
# feature_vector: -0.0167738367
# feature_vector: 0.0586911291
# feature_vector: 0.0142602921
# feature_vector: -0.0661856383
# feature_vector: -0.037001092
# feature_vector: 0.0213637874
# feature_vector: -0.0669554323
# feature_vector: -0.00116335927
# feature_vector: 0.0383559801
# feature_vector: -0.038278155
# feature_vector: 0.0308390725
# feature_vector: -0.0408278294
# feature_vector: 0.061459031
# feature_vector: -0.0813848302
# feature_vector: 0.00729028042
# feature_vector: -0.00775805162
# feature_vector: 0.000201907402
# feature_vector: 0.015848998
# feature_vector: 0.00776004465
# feature_vector: 0.0357160047
# feature_vector: -0.0127200931
# feature_vector: -0.0317522027
# feature_vector: -0.0547341
# feature_vector: 0.0177926049
# feature_vector: 0.0422197916
# feature_vector: -0.0339118168
# feature_vector: -0.0129224518
# feature_vector: -0.0143293869
# feature_vector: -0.0580702797
# feature_vector: 0.0244321916
# feature_vector: 0.00311275315
# feature_vector: 0.0185149014
# feature_vector: 0.0518827774
# feature_vector: 0.0122198816
# feature_vector: -0.0370541103
# feature_vector: 0.0419330336
# feature_vector: -0.00818146206
# feature_vector: 0.00425227
# feature_vector: -0.0191517286
# feature_vector: 0.00262784492
# feature_vector: -0.0141322222
# feature_vector: -0.0202335492
# feature_vector: -0.00137643307
# feature_vector: 0.0186562
# feature_vector: -0.00011941565
# feature_vector: 0.0315961428
# feature_vector: 0.0190500785
# feature_vector: -0.0267440155
# feature_vector: -0.0390186645
# feature_vector: 0.0692165568
# feature_vector: -0.0671101
# feature_vector: 0.00439819787
# feature_vector: -0.0243766848
# feature_vector: 0.027756663
# feature_vector: 0.0116632078
# feature_vector: 0.0122463489
# feature_vector: 0.00221237494
# feature_vector: -0.0965766
# feature_vector: 0.0438557789
# feature_vector: -0.0271636602
# feature_vector: -0.00899618678
# feature_vector: 0.0526812598
# feature_vector: 0.0234556124
# feature_vector: 0.00800353754
# feature_vector: 0.101154387
# feature_vector: -0.0434303284
# feature_vector: -0.00152854668
# feature_vector: 0.0196774192
# feature_vector: -0.00285664364
# feature_vector: 0.0147349201
# feature_vector: 0.0212089643
# feature_vector: -0.0407993495
# feature_vector: 0.0550391749
# feature_vector: -0.042993322
# feature_vector: 0.0322886519
# feature_vector: -0.014958065
# feature_vector: 0.0217794366
# feature_vector: 0.033348728
# feature_vector: -0.030748263
# feature_vector: 0.0240805428
# feature_vector: 0.0372613594
# feature_vector: 0.00248457771
# feature_vector: -0.0422494523
# feature_vector: 0.0194451082
# feature_vector: -0.0389219
# feature_vector: 0.0427766889
# feature_vector: 0.0138044693
# feature_vector: 0.023665987
# feature_vector: 0.0127923153
# feature_vector: -0.0018932058
# feature_vector: 0.0293130968
# feature_vector: -0.0380443297
# feature_vector: -0.0278605931
# feature_vector: -0.00892984495
# feature_vector: -0.0306419618
# feature_vector: -0.0354310833
# feature_vector: -0.0421696827
# feature_vector: 0.0347072594
# feature_vector: -0.0372693092
# feature_vector: -0.00360706891
# feature_vector: -0.0433867499
# feature_vector: -0.018506458
# feature_vector: 0.0476838499
# feature_vector: 0.0344704576
# feature_vector: -0.0360054895
# feature_vector: 0.0149898287
# feature_vector: 0.0403122194
# feature_vector: -0.0523806699
# feature_vector: 0.00408152025
# feature_vector: 0.0627422407
# feature_vector: 0.0190570615
# feature_vector: 0.0670009255
# feature_vector: 0.0521414839
# feature_vector: 0.0139807109
# feature_vector: 0.00725775
# feature_vector: -0.043541152
# feature_vector: 0.0197396185
# feature_vector: -0.0435254313
# feature_vector: 0.0277378689
# feature_vector: 0.0232590921
# feature_vector: -0.0335289538
# feature_vector: -0.0218163896
# feature_vector: -0.0148882112
# feature_vector: 0.0240397379
# feature_vector: 0.00421332568
# feature_vector: -0.0606101118
# feature_vector: 0.0652836189
# feature_vector: 0.000595340796
# feature_vector: -0.110627182
# feature_vector: -0.0700323954
# feature_vector: -0.0321000889
# feature_vector: -0.0177191664
# feature_vector: -0.006864917
# feature_vector: 0.0230444353
# feature_vector: -0.00799083337
# feature_vector: 0.0130438535
# feature_vector: -0.0184979402
# feature_vector: -0.0365003347
# feature_vector: -0.0500740223
# feature_vector: 0.0301067792
# feature_vector: -0.000743330049
# feature_vector: -0.0152637847
# feature_vector: -0.0195413791
# feature_vector: -0.015719
# feature_vector: 0.0120286541
# feature_vector: -0.0304337814
# feature_vector: 0.0180337597
# feature_vector: -0.089265421
# feature_vector: -0.0628961325
# feature_vector: -0.0494562611
# feature_vector: 0.0501667373
# feature_vector: -0.0114877718
# feature_vector: -0.0311037619
# feature_vector: 0.0680649504
# feature_vector: -0.0235148463
# feature_vector: 0.0328851305
# feature_vector: -0.0028077513
# feature_vector: -0.0345664211
# feature_vector: 0.0439536721
# feature_vector: -0.00839440804
# feature_vector: -0.0330284946
# feature_vector: -0.0059951
# feature_vector: 0.00889660511
# feature_vector: -0.0347605981
# feature_vector: 0.0475746132
# feature_vector: 0.0213740021
# feature_vector: 0.050191164
# feature_vector: 0.0372342318
# feature_vector: 0.0527495
# feature_vector: -0.0110841598
# feature_vector: -0.0179456566
# feature_vector: 0.039664723
# feature_vector: -0.0423101
# feature_vector: 0.0439947098
# feature_vector: 0.0287558679
# feature_vector: 0.0345797837
# feature_vector: 0.0210045036
# feature_vector: -0.0389650948
# feature_vector: 0.00390444882
# feature_vector: 0.0287968516
# feature_vector: 0.0216772575
# feature_vector: -0.0363855548
# feature_vector: -0.0186794605
# feature_vector: 0.0229367465
# feature_vector: 0.0246861409
# feature_vector: 0.0199758131
# feature_vector: 0.00564809656
# feature_vector: 0.0148595702
# feature_vector: 0.00722638052
# feature_vector: 0.0309949107
# feature_vector: 0.054927364
# feature_vector: 0.0323916487
# feature_vector: -0.0577076338
# feature_vector: -0.0502058193
# feature_vector: 0.079163149
# feature_vector: 0.0116152931
# feature_vector: -0.0267878398
# feature_vector: -0.00316541386
# feature_vector: 0.0871905535
# feature_vector: -0.0233991947
# feature_vector: 0.0171863139
# feature_vector: 0.0419924036
# feature_vector: 0.0449939705
# feature_vector: 0.0223363526
# feature_vector: -0.0313055292
# feature_vector: -0.023901483
# feature_vector: 0.0752507448
# feature_vector: -0.0199845284
# feature_vector: 0.00794991
# feature_vector: -0.0292287171
# feature_vector: 0.0195871647
# feature_vector: 0.0255253799
# feature_vector: -0.0108307879
# feature_vector: -0.0200358424
# feature_vector: 0.0356483571
# feature_vector: 0.0136131253
# feature_vector: 0.068655014
# feature_vector: 0.0161413923
# feature_vector: 0.0255794451
# feature_vector: -0.00321175507
# feature_vector: -0.0642521232
# feature_vector: -0.0204645749
# feature_vector: -0.00385413319
# feature_vector: 0.0702054128
# feature_vector: 0.0548479855
# feature_vector: 0.0195362493
# feature_vector: -0.0255598929
# feature_vector: 0.0222057253
# feature_vector: -0.0347354747
# feature_vector: -0.0205222815
# feature_vector: -0.0636413693
# feature_vector: -0.024992032
# feature_vector: -0.00334773911
# feature_vector: -0.0623267889
# feature_vector: 0.0805459619
# feature_vector: 0.0515596978
# feature_vector: -0.00126514037
# feature_vector: -0.0170316659
# feature_vector: -0.0166121423
# feature_vector: 0.0148273194
# feature_vector: -0.0246267542
# feature_vector: -0.0104404064
# feature_vector: 0.0281725135
# feature_vector: 0.00417140685
# feature_vector: -0.00640386203
# feature_vector: 0.0267748144
# feature_vector: 0.0477359332
# feature_vector: -0.0652224198
# feature_vector: 0.0114628896
# crowding_tag {
#   crowding_attribute: "0"
# }
# ]

# %% [markdown]
# ## Retrieve text chunks represented by the nearest neighbor embeddings
#
# The embeddings are used for performing similarity/neighbor search in the vector space.
#
# If we want to implement a RAG use case, however, the embeddings by themselves are not meaningful to include in the context for interacting with a generative model.
#
# For that reason, we need to retrieve the text chunks that are associated with the nearest neighbor embeddings.
#
# The following code will do that.

# %%
# Extract IDs from the response
neighbor_ids = [neighbor.id for neighbor in response[0]]  # Access the first (and likely only) list in the response

# Fetch the text chunks corresponding to given IDs from the JSONL file
def fetch_text_chunks(ids, filename=filename):
    texts = {}
    with open(filename, 'r') as file:
        for line in file:
            data = json.loads(line)
            if str(data['id']) in ids:  # Ensure the id from JSON is treated as a string for matching
                texts[str(data['id'])] = data['text']
    return [texts[id] for id in ids if id in texts]

# Fetch the corresponding texts using the IDs extracted
neighbor_texts = fetch_text_chunks([str(id) for id in neighbor_ids], filename=filename)  

# Now we have the embeddings and their corresponding text chunks
print(neighbor_texts)
# Out:
# ['# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\n## CGM\n\n### TABLE 1\n\nBaseline characteristics of the study participants', '# Effect of cinnamon spice on continuously monitored glycemic response in adults with prediabetes: a 4-week randomized controlled crossover trial\n\nHila Zelicha¹, Jieping Yang 2, Susanne M Henning 2, Jianjun Huang 2, Ru-Po Lee2, Gail Thames 2, Edward H Livingston¹, David Heber², Zhaoping Li 2,* Department of Surgery, University of California, Los Angeles, Los Angeles, CA, United States; 2 Department of Medicine, Center for Human Nutrition, David Geffen School of Medicine, Los Angeles, United States', '# Appendix A. Supplementary data\n\n## References\n\n### H. Zelicha et al.\n\n[54] M.L. Silva, M.A. Bernardo, J. Singh, M.F. de Mesquita, Cinnamon as a complementary therapeutic approach for dysglycemia and dyslipidemia control in type 2 diabetes mellitus and its molecular mechanism of action: a review, Nutrients 14 (13) (2022) 2773. [55] Q.Y. Lu, P.H. Summanen, R.P. Lee, J. Huang, S.M. Henning, D. Heber, et al., Prebiotic potential and chemical composition of seven culinary spice extracts, J Food Sci 82 (8) (2017) 1807-1813. [56] Q.Y. Lu, A.M. Rasmussen, J. Yang, R.P. Lee, J. Huang, P. Shao, et al., Mixed spices at culinary doses have prebiotic effects in healthy adults: A pilot study, Nutrients 11 (6) (2019).']

# %%
print(neighbor_ids)
# Out:
# ['25', '1', '63']

# %% [markdown]
# ## Use retrieved content with generative AI model
#
# To implement a RAG use case, we can include the retrieved content as context when sending a prompt to a generative AI model.
#
# The following code will send a prompt to Gemini, and will include our retrieved text chunks as context.

# %% [markdown]
# ### First, send a simple prompt to Gemini, without context.

# %%
import vertexai

from vertexai.generative_models import GenerativeModel, ChatSession

vertexai.init(project=PROJECT_ID, location=REGION)
model = GenerativeModel(model_name="gemini-1.0-pro-002")
chat = model.start_chat()

def get_chat_response(chat: ChatSession, prompt: str) -> str:
    text_response = []
    responses = chat.send_message(prompt, stream=True)
    for chunk in responses:
        text_response.append(chunk.text)
    return "".join(text_response)

# Using our query text from earlier
prompt = query_text
print(get_chat_response(chat, prompt))
# Out:
# ##  Cinnamon and Prediabetes Management: Dietary and Lifestyle Interactions
#
# Cinnamon, a popular spice, has garnered interest for its potential role in managing prediabetes. While research is ongoing, evidence suggests cinnamon may offer benefits when combined with other dietary and lifestyle interventions.
#
# **Dietary Interactions:**
#
# * **Fiber:** Combining cinnamon with high-fiber foods can amplify its blood sugar-lowering effects. Fiber slows down digestion and carbohydrate absorption, leading to a more gradual rise in blood sugar levels.
# * **Low-Glycemic Index (GI) Foods:** Pairing cinnamon with low-GI foods further contributes to better blood sugar control. These foods cause a slower and smaller rise in blood sugar compared to high-GI foods.
# * **Antioxidant-Rich Foods:** Combining cinnamon with antioxidant-rich fruits, vegetables, and nuts can offer additional benefits. Antioxidants may help protect against oxidative stress, a factor associated with diabetes development.
#
# **Lifestyle Interactions:**
#
# * **Physical Activity:** Regular physical activity, especially moderate-intensity exercise, improves insulin sensitivity and helps manage blood sugar levels. Combining cinnamon with exercise can potentially enhance these effects.
# * **Weight Management:** Maintaining a healthy weight is crucial for prediabetes management. Cinnamon, when combined with a balanced diet and regular exercise, may support weight loss efforts.
# * **Stress Management:** Chronic stress can negatively impact blood sugar control. Incorporating stress-reducing techniques like yoga, meditation, or deep breathing alongside cinnamon consumption may be beneficial.
#
# **Important Considerations:**
#
# * **Limited Research:** While research on cinnamon and prediabetes is promising, more studies are needed to confirm its effectiveness and optimal dosage.
# * **Individual Variability:**  Responses to cinnamon can vary depending on individual factors like genetics and overall health. Consulting a healthcare professional is crucial to determine the appropriate approach for each person.
# * **Potential Side Effects:** Cinnamon is generally safe for most people when consumed in moderate amounts. However, high doses may cause side effects like mouth sores, diarrhea, and lowered blood sugar levels.
#
# **Conclusion:**
#
# Cinnamon, as part of a comprehensive approach that includes dietary modifications, regular exercise, weight management, and stress reduction, may offer additional benefits for managing prediabetes. However, further research is needed to fully understand its role and optimal use.
#
# It's important to remember that cinnamon is not a magic bullet and should be used in conjunction with other healthy lifestyle choices. Consulting a healthcare professional can provide personalized guidance on incorporating cinnamon into a prediabetes management plan.

# %% [markdown]
# ### Provide context
#
# In the next prompt, we provide our retrieved text chunks as context.

# %%
prompt = f"{query_text} in the context of:{neighbor_texts}"
print(get_chat_response(chat, prompt))
# Out:
# ## Cinnamon and Prediabetes Management: Interactions with Other Interventions
#
# Your provided references offer valuable information on the potential of cinnamon in managing prediabetes, particularly in the context of a 4-week randomized controlled crossover trial. Here's an analysis of how cinnamon might interact with other dietary and lifestyle interventions based on the provided context:
#
# **Dietary Interactions:**
#
# * **Fiber and Low-GI Foods:** The study design doesn't explicitly mention the participants' dietary intake of fiber or low-GI foods. However, it's important to note that a balanced diet rich in fiber and low-GI options would likely enhance the blood sugar-lowering effects observed with cinnamon supplementation.
# * **Antioxidant-Rich Foods:** Similarly, the study doesn't detail the participants' intake of antioxidant-rich foods. Nevertheless, including plenty of fruits, vegetables, and nuts alongside cinnamon could offer additional benefits for managing oxidative stress, a contributing factor to diabetes development.
#
# **Lifestyle Interactions:**
#
# * **Physical Activity:** The study doesn't provide information about the participants' physical activity levels. However, it's crucial to remember that regular exercise is essential for improving insulin sensitivity and managing blood sugar levels. Combining cinnamon with an active lifestyle could potentially amplify these positive effects.
# * **Weight Management:** The study doesn't report participants' weight or weight management efforts. Maintaining a healthy weight is crucial for prediabetes management. Combining cinnamon with a balanced diet and regular exercise could potentially support weight loss efforts. However, more research is needed to confirm this interaction specifically.
# * **Stress Management:** The study doesn't mention participants' stress levels or stress management strategies. Nonetheless, chronic stress can negatively impact blood sugar control. Incorporating stress-reducing techniques like yoga, meditation, or deep breathing alongside cinnamon consumption might be beneficial.
#
# **Additional Insights from the References:**
#
# * Reference [54] highlights the potential of cinnamon as a complementary therapeutic approach for dysglycemia and dyslipidemia control in type 2 diabetes mellitus. This suggests that cinnamon could play a role in managing various aspects of metabolic disorders.
# * Reference [55] explores the prebiotic potential of seven culinary spice extracts, including cinnamon. This implies that cinnamon might positively impact gut health, which could further contribute to improved blood sugar control.
# * Reference [56] investigates the prebiotic effects of mixed spices, including cinnamon, in healthy adults. This suggests that cinnamon's benefits might extend beyond individuals with prediabetes and could be relevant for overall health maintenance.
#
# **Conclusion:**
#
# While the provided study provides valuable insights into the potential of cinnamon for prediabetes management, it doesn't explicitly address interactions with other dietary or lifestyle interventions. However, based on available research and general recommendations for managing prediabetes, it's safe to assume that cinnamon's effects can be amplified when combined with a comprehensive approach that includes:
#
# * A balanced diet rich in fiber, low-GI foods, and antioxidants
# * Regular physical activity
# * Weight management efforts
# * Stress management techniques
#
# Further research is needed to fully understand the interactions between cinnamon and other interventions for prediabetes management and to determine the optimal dosage and duration of supplementation. Additionally, individual factors like genetics and overall health should be considered when formulating a personalized approach. Consulting a healthcare professional remains crucial for tailored guidance on incorporating cinnamon into a prediabetes management plan.

# %% [markdown]
# ### Try with precise answers only from the source document
#
# In this case, we instruct the model to answer only from the retrieved context.

# %%
prompt = f"{query_text} Answer only from the following context:{neighbor_texts}"
print(get_chat_response(chat, prompt))
# Out:
# ## Cinnamon Supplementation and Prediabetes Management: Interactions from Specific Context
#
# Based solely on the provided references, which discuss a  study on cinnamon's effect on prediabetes using Continuous Glucose Monitoring (CGM), here's an analysis of potential interactions with dietary and lifestyle interventions:
#
# **Dietary Interactions:**
#
# * **Limited Information:  The provided context doesn't offer details  about participants' dietary intake. Therefore, it's impossible to  conclusively determine interactions based solely on this limited data.  A broader understanding requires information on dietary factors like  fiber, Glycemic Index (GI), and antioxidant intake.**
#  * **General Recommendations: The general recommendations for prediabetes management still apply. Combining cinnamon with a balanced diet rich in fiber, low-GI foods, and antioxidants would likely maximize potential benefits. However, it's critical to consult a healthcare professional for specific dietary guidance considering individual needs.*
#
# **Lifestyle Interactions:**
#
# * **Physical Activity:** Similarly, the provided study doesn't mention participants' physical activity levels. Nonetheless, consistent exercise is crucial for improved insulin sensitivity and blood sugar control. Combining cinnamon with an active lifestyle could potentially augment these positive effects. However, research specifically investigating this interaction with  prediabetes is limited within this  context.**
#
#  * **Weight Management:  Again, no weight data or information  related to weight management efforts are available within this context. Maintaining a healthy weight is crucial. Combining cinnamon with a balanced diet and regular exercise might support weight loss, but research needs to  specifically evaluate such interaction within the context of a  prediabetes intervention for better clarity.*
#
#  **Stress Management: Similar  limitations regarding stress management exist as in other categories mentioned above.**
# * **General  Recommendations: Consistent with overall prediabetes management  recommendations, combining cinnamon with stress-reducing techniques might offer additional benefits. Techniques like yoga, meditation, or deep breathing  could help mitigate stress, which may improve blood sugar control. However, specific research in a prediabetes context  with this  approach within our limited references needs to be considered and further exploration is crucial.*
# **Conclusion:**
#
# Despite the lack of explicit interactions within the specific context of the provided studies, general insights recommend considering cinnamon alongside other healthy lifestyle changes for effective prediabetes management: a balanced diet, physical activity, weight management, and stress reduction.
#
# Individual variations and the need for a customized approach remain crucial. Consultation with a healthcare professional based on comprehensive information can ensure optimal strategies for each individual with prediabetes. This tailored approach is necessary for safe and effective cinnamon integration within a holistic management plan while accounting for unique factors.
#
# For a thorough understanding, additional research exploring cinnamon's specific interactions within a prediabetic context with other intervention types is vital. This can offer more conclusive evidence and support individualized treatment strategies for managing prediabetes.

# %% [markdown]
# # That's it! Well Done!

# %% [markdown]
# # Clean up
#
# When you no longer need the resources created by this notebook. You can delete them as follows.
#
# **Note: if you do not delete the resources, you will continue to pay for them.**

# %%
clean_up = True

# %% [markdown]
# ## Delete the Document AI Processor

# %%
from google.api_core import exceptions as gcp_exceptions
if clean_up:
    try:
        client.delete_processor(name=processor_name)
        print(f"Deleted Processor: {processor_name}")
    except gcp_exceptions.NotFound:
        print(f"Processor not found: {processor_name}")
else:
    print("clean_up parameter is set to False")
# Out:
# Deleted Processor: projects/714662258896/locations/us/processors/e3e6ae448e857d12

# %% [markdown]
# ## Delete the Vertex Vector Search Index

# %%
if clean_up:
    try:
        vvs_index.delete()  # Set force=True to bypass the check for deployed indexes
        print(f"Deleted Matching Engine Index: {index.resource_name}")
    except gcp_exceptions.NotFound:
        print(f"Index not found: {index.resource_name}")
    except Exception as e:
        print(f"Error deleting index: {e}")
else:
    print("clean_up parameter is set to False")
# Out:
# Deleting MatchingEngineIndex : projects/714662258896/locations/us-central1/indexes/7631309986160705536
# MatchingEngineIndex deleted. . Resource name: projects/714662258896/locations/us-central1/indexes/7631309986160705536
# Deleting MatchingEngineIndex resource: projects/714662258896/locations/us-central1/indexes/7631309986160705536
# Delete MatchingEngineIndex backing LRO: projects/714662258896/locations/us-central1/indexes/7631309986160705536/operations/2125060104783921152
# MatchingEngineIndex resource projects/714662258896/locations/us-central1/indexes/7631309986160705536 deleted.
# Error deleting index: name 'index' is not defined

# %% [markdown]
# ## Delete the Vertex Vector Search Endpoint

# %%
if clean_up:
    try:
        # Undeploy the deployed index
        try:
            vvs_index_endpoint.undeploy_index(deployed_index_id=DEPLOYED_INDEX_ID)
            print(f"Undeployed index '{DEPLOYED_INDEX_ID}' from endpoint '{vvs_index_endpoint.name}'.")
        except exceptions.NotFound:
            print(f"Deployed index '{DEPLOYED_INDEX_ID}' not found in endpoint '{vvs_index_endpoint.name}'.")
        
        # Delete the index endpoint
        vvs_index_endpoint.delete()
        print(f"Deleted index endpoint: {vvs_index_endpoint.name}")

    except exceptions.NotFound:
        print(f"Index endpoint not found: {vvs_index_endpoint.name}")
else:
    print("clean_up parameter is set to False")
# Out:
# Undeploying index MatchingEngineIndexEndpoint index_endpoint: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# Undeploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680/operations/208215513384353792
# MatchingEngineIndexEndpoint index_endpoint Undeployed index. Resource name: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# Undeployed index 'deployed_index_01201941' from endpoint '661004400386375680'.
# Deleting MatchingEngineIndexEndpoint : projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# MatchingEngineIndexEndpoint deleted. . Resource name: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# Deleting MatchingEngineIndexEndpoint resource: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680
# Delete MatchingEngineIndexEndpoint backing LRO: projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680/operations/1363951767758307328
# MatchingEngineIndexEndpoint resource projects/714662258896/locations/us-central1/indexEndpoints/661004400386375680 deleted.
# Deleted index endpoint: 661004400386375680

# %% [markdown]
# ## Delete GCS Bucket
# The bucket can be reused throughout multiple activities in the book. Sometimes, activities in certain chapters make use of artifacts from previous chapters that are stored in the GCS bucket.
#
# I highly recommend **not deleting the bucket** unless you will be performing no further activities in the book. For this reason, there's a separate `delete_bucket` variable to specify if you want to delete the bucket.
#
# If you want to delete the bucket, set the `delete_bucket` parameter to `True`.

# %%
delete_bucket = False

# %%
if delete_bucket == True:
    # Delete the bucket
    ! gcloud storage rm --recursive gs://$BUCKET
else:
    print("delete_bucket parameter is set to False")
